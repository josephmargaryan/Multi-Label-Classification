# %%
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
import optuna
from sklearn.metrics import roc_auc_score
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
import pickle

# %%
train = pd.read_csv("/kaggle/input/playground-series-s4e3/train.csv")
train_original = pd.read_csv("/kaggle/input/steel-fault/faults.csv")

train.drop(columns=['id'], axis=1, inplace=True)
target_cols = ['Pastry','Z_Scratch','K_Scatch','Stains','Dirtiness','Bumps','Other_Faults']
train = train[train[target_cols].sum(axis=1) == 1]

# %%
test = pd.concat([train_original, train], axis=0)

# %%
def feature_generator(data):

    "A function to generate additional features"

    epsilon = 1e-6  # A small constant to avoid division by zero or taking the logarithm of zero
    # Location Features
    data['X_Distance'] = data['X_Maximum'] - data['X_Minimum']
    data['Y_Distance'] = data['Y_Maximum'] - data['Y_Minimum']

    # Density Feature
    data['Density'] = data['Pixels_Areas'] / (data['X_Perimeter'] + data['Y_Perimeter'])

    # Relative Perimeter Feature
    data['Relative_Perimeter'] = data['X_Perimeter'] / (data['X_Perimeter'] + data['Y_Perimeter'] + epsilon)

    # Circularity Feature
    data['Circularity'] = data['Pixels_Areas'] / (data['X_Perimeter'] ** 2)

    # Symmetry Index Feature
    data['Symmetry_Index'] = np.abs(data['X_Distance'] - data['Y_Distance']) / (data['X_Distance'] + data['Y_Distance'] + epsilon)
    
    # Color Contrast Feature
    data['Color_Contrast'] = data['Maximum_of_Luminosity'] - data['Minimum_of_Luminosity']

    # Combined Geometric Index Feature
    data['Combined_Geometric_Index'] = data['Edges_Index'] * data['Square_Index']

    # Interaction Term Feature
    data['X_Distance*Pixels_Areas'] = data['X_Distance'] * data['Pixels_Areas']
    
    # Additional Features
    data['sin_orientation'] = np.sin(data['Orientation_Index'])
    data['Edges_Index2'] = np.exp(data['Edges_Index'] + epsilon)
    data['X_Maximum2'] = np.sin(data['X_Maximum'])
    data['Y_Minimum2'] = np.sin(data['Y_Minimum'])
    data['Aspect_Ratio_Pixels'] = np.where(data['Y_Perimeter'] == 0, 0, data['X_Perimeter'] / data['Y_Perimeter'])
    data['Aspect_Ratio'] = np.where(data['Y_Distance'] == 0, 0, data['X_Distance'] / data['Y_Distance'])

    # Average Luminosity Feature
    data['Average_Luminosity'] = (data['Sum_of_Luminosity'] + data['Minimum_of_Luminosity']) / 2
    
    # Normalized Steel Thickness Feature
    data['Normalized_Steel_Thickness'] = (data['Steel_Plate_Thickness'] - data['Steel_Plate_Thickness'].min()) / (data['Steel_Plate_Thickness'].max() - data['Steel_Plate_Thickness'].min())

    # Logarithmic Features
    data['Log_Perimeter'] = np.log(data['X_Perimeter'] + data['Y_Perimeter'] + epsilon)
    data['Log_Luminosity'] = np.log(data['Sum_of_Luminosity'] + epsilon)
    data['Log_Aspect_Ratio'] = np.log(data['Aspect_Ratio'] ** 2 + epsilon)

    # Statistical Features
    data['Combined_Index'] = data['Orientation_Index'] * data['Luminosity_Index']
    data['Sigmoid_Areas'] = 1 / (1 + np.exp(-data['LogOfAreas'] + epsilon))

    return data

test = feature_generator(test)

# %%
# Initialize the scaler
scaler = RobustScaler()

# Identify discrete features
discrete_features = ['TypeOfSteel_A300', 'TypeOfSteel_A400']

# Identify continuous features
continuous_features = [col for col in test.columns if col not in discrete_features + target_cols]

# Fit and transform the scaler on training data
test[continuous_features] = scaler.fit_transform(test[continuous_features])

# %%
X = test.drop(columns=target_cols, axis=1)
y1 = test['Pastry']
y2 = test['Z_Scratch']
y3 = test['K_Scatch']
y4 = test['Stains']
y5 = test['Dirtiness']
y6 = test['Bumps']
y7 = test['Other_Faults']

# %%
X_train_Pastry, X_test_pastry, y_train_Pastry, y_test_pastry = train_test_split(X, y1, test_size=0.3, random_state=24)
X_train_Z_Scratch, X_test_Z_Scratch, y_train_Z_Scratch, y_test_Z_Scratch = train_test_split(X, y2, test_size=0.3, random_state=24)
X_train_K_Scatch, X_test_K_Scatch, y_train_K_Scatch, y_test_K_Scatch = train_test_split(X, y3, test_size=0.3, random_state=24)
X_train_Stains, X_test_Stains, y_train_Stains, y_test_Stains = train_test_split(X, y4, test_size=0.3, random_state=24)
X_train_Dirtiness, X_test_Dirtiness, y_train_Dirtiness, y_test_Dirtiness = train_test_split(X, y5, test_size=0.3, random_state=24)
X_train_Bumps, X_test_Bumps, y_train_Bumps, y_test_Bumps = train_test_split(X, y6, test_size=0.3, random_state=24)
X_train_Other_Faults, X_test_Other_Faults, y_train_Other_Faults, y_test_Other_Faults = train_test_split(X, y7, test_size=0.3, random_state=24)

# %%
# Assuming target_splits is the dictionary containing splits for each target
target_splits = {
    'Pastry': (X_train_Pastry, X_test_pastry, y_train_Pastry, y_test_pastry),
    'Z_Scratch': (X_train_Z_Scratch, X_test_Z_Scratch, y_train_Z_Scratch, y_test_Z_Scratch),
    'K_Scatch': (X_train_K_Scatch, X_test_K_Scatch, y_train_K_Scatch, y_test_K_Scatch),
    'Stains': (X_train_Stains, X_test_Stains, y_train_Stains, y_test_Stains),
    'Dirtiness': (X_train_Dirtiness, X_test_Dirtiness, y_train_Dirtiness, y_test_Dirtiness),
    'Bumps': (X_train_Bumps, X_test_Bumps, y_train_Bumps, y_test_Bumps),
    'Other_Faults': (X_train_Other_Faults, X_test_Other_Faults, y_train_Other_Faults, y_test_Other_Faults)
}

# %%
# Define the objective function
def objective_cat(trial, X_train, X_test, y_train, y_test):
    # Define the search space for CatBoost hyperparameters
    cat_params = {
        'iterations': trial.suggest_int('iterations', 100, 1000),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
        'depth': trial.suggest_int('depth', 1, 10),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.05, 1),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 1, 100)
    }
    model_cat = CatBoostClassifier(**cat_params)
    model_cat.fit(X_train, y_train, verbose=False)
    predictions_cat = model_cat.predict(X_test)
    accuracy_cat = roc_auc_score(y_test, predictions_cat)
    return accuracy_cat

# Dictionary to store best models for each target
best_models_cat = {}

# Loop over each target
for target, (X_train, X_test, y_train, y_test) in target_splits.items():
    print(f"Tuning catBoost for target: {target}")
    study_cat = optuna.create_study(direction='maximize')
    study_cat.optimize(lambda trial: objective_cat(trial, X_train, X_test, y_train, y_test), n_trials=30)
    print('Best hyperparameters:', study_cat.best_params)
    print('Best accuracy:', study_cat.best_value)

    # Define the best hyperparameters obtained from Optuna
    best_params_cat = study_cat.best_params

    # Instantiate CatBoostClassifier with the best hyperparameters
    best_cat_model = CatBoostClassifier(**best_params_cat, silent=True)

    # Fit the model on the training data
    best_cat_model.fit(X_train, y_train)

    # Save the model to a file
    model_filename = f"best_cat_model_{target}.pkl"
    with open(model_filename, 'wb') as f:
        pickle.dump(best_cat_model, f)

    # Store the model in the dictionary
    best_models_cat[target] = best_cat_model
# Out:
# [I 2024-03-22 07:19:17,466] A new study created in memory with name: no-name-3f07d658-5e47-4260-828d-866cf2e8c62d
# Tuning catBoost for target: Pastry
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:19:22,984] Trial 0 finished with value: 0.5357799899193548 and parameters: {'iterations': 812, 'learning_rate': 0.010717023490815806, 'depth': 4, 'colsample_bylevel': 0.9629101163702997, 'min_data_in_leaf': 90}. Best is trial 0 with value: 0.5357799899193548.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:19:23,588] Trial 1 finished with value: 0.5 and parameters: {'iterations': 176, 'learning_rate': 0.024457246970361116, 'depth': 1, 'colsample_bylevel': 0.6209023708827925, 'min_data_in_leaf': 25}. Best is trial 0 with value: 0.5357799899193548.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:19:36,346] Trial 2 finished with value: 0.5307488315615836 and parameters: {'iterations': 363, 'learning_rate': 0.009467406752512167, 'depth': 8, 'colsample_bylevel': 0.7322663480425987, 'min_data_in_leaf': 19}. Best is trial 0 with value: 0.5357799899193548.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:19:41,914] Trial 3 finished with value: 0.5611524773949169 and parameters: {'iterations': 864, 'learning_rate': 0.02572217208842053, 'depth': 4, 'colsample_bylevel': 0.8700174427955241, 'min_data_in_leaf': 63}. Best is trial 3 with value: 0.5611524773949169.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:19:43,203] Trial 4 finished with value: 0.5242084402492668 and parameters: {'iterations': 265, 'learning_rate': 0.016739579866116634, 'depth': 3, 'colsample_bylevel': 0.5728720863793575, 'min_data_in_leaf': 85}. Best is trial 3 with value: 0.5611524773949169.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:19:57,413] Trial 5 finished with value: 0.5443821404569893 and parameters: {'iterations': 893, 'learning_rate': 0.00972610843608311, 'depth': 7, 'colsample_bylevel': 0.4147821532192974, 'min_data_in_leaf': 96}. Best is trial 3 with value: 0.5611524773949169.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:20:07,040] Trial 6 finished with value: 0.5605211006231671 and parameters: {'iterations': 379, 'learning_rate': 0.09854322704528279, 'depth': 10, 'colsample_bylevel': 0.1512712539446462, 'min_data_in_leaf': 25}. Best is trial 3 with value: 0.5611524773949169.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:20:13,691] Trial 7 finished with value: 0.5 and parameters: {'iterations': 721, 'learning_rate': 0.0010480904064219092, 'depth': 6, 'colsample_bylevel': 0.38980619305737446, 'min_data_in_leaf': 20}. Best is trial 3 with value: 0.5611524773949169.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:20:17,748] Trial 8 finished with value: 0.5653747021627565 and parameters: {'iterations': 997, 'learning_rate': 0.04683378829954839, 'depth': 3, 'colsample_bylevel': 0.2847529239565711, 'min_data_in_leaf': 72}. Best is trial 8 with value: 0.5653747021627565.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:20:23,677] Trial 9 finished with value: 0.5 and parameters: {'iterations': 305, 'learning_rate': 0.002004977945171912, 'depth': 7, 'colsample_bylevel': 0.962950959750179, 'min_data_in_leaf': 13}. Best is trial 8 with value: 0.5653747021627565.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:20:25,256] Trial 10 finished with value: 0.5461974202712611 and parameters: {'iterations': 618, 'learning_rate': 0.09974075175781476, 'depth': 1, 'colsample_bylevel': 0.11538232452002889, 'min_data_in_leaf': 58}. Best is trial 8 with value: 0.5653747021627565.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:20:30,433] Trial 11 finished with value: 0.5610736268939394 and parameters: {'iterations': 989, 'learning_rate': 0.035893010856740015, 'depth': 4, 'colsample_bylevel': 0.2864244707791403, 'min_data_in_leaf': 63}. Best is trial 8 with value: 0.5653747021627565.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:20:36,000] Trial 12 finished with value: 0.5671701261608015 and parameters: {'iterations': 947, 'learning_rate': 0.04201672832231828, 'depth': 3, 'colsample_bylevel': 0.7948242184918771, 'min_data_in_leaf': 71}. Best is trial 12 with value: 0.5671701261608015.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:20:38,930] Trial 13 finished with value: 0.5622277462121212 and parameters: {'iterations': 529, 'learning_rate': 0.04809263335022478, 'depth': 3, 'colsample_bylevel': 0.7396526345981547, 'min_data_in_leaf': 78}. Best is trial 12 with value: 0.5671701261608015.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:20:42,509] Trial 14 finished with value: 0.5117391785801564 and parameters: {'iterations': 993, 'learning_rate': 0.004038702851099032, 'depth': 2, 'colsample_bylevel': 0.3572024340862846, 'min_data_in_leaf': 42}. Best is trial 12 with value: 0.5671701261608015.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:20:46,756] Trial 15 finished with value: 0.5617937820747801 and parameters: {'iterations': 710, 'learning_rate': 0.0571191732268439, 'depth': 5, 'colsample_bylevel': 0.2561329742547096, 'min_data_in_leaf': 74}. Best is trial 12 with value: 0.5671701261608015.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:20:48,764] Trial 16 finished with value: 0.5448458883186705 and parameters: {'iterations': 505, 'learning_rate': 0.05222355936138838, 'depth': 2, 'colsample_bylevel': 0.46623362214650116, 'min_data_in_leaf': 49}. Best is trial 12 with value: 0.5671701261608015.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:20:55,073] Trial 17 finished with value: 0.5487819220430108 and parameters: {'iterations': 775, 'learning_rate': 0.018194252574415697, 'depth': 5, 'colsample_bylevel': 0.7137289848954822, 'min_data_in_leaf': 42}. Best is trial 12 with value: 0.5671701261608015.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:21:00,154] Trial 18 finished with value: 0.5252837090664711 and parameters: {'iterations': 919, 'learning_rate': 0.005056278811042578, 'depth': 3, 'colsample_bylevel': 0.8313713380964526, 'min_data_in_leaf': 100}. Best is trial 12 with value: 0.5671701261608015.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:21:01,998] Trial 19 finished with value: 0.5439481763196481 and parameters: {'iterations': 632, 'learning_rate': 0.06833426129071297, 'depth': 2, 'colsample_bylevel': 0.052470650202997404, 'min_data_in_leaf': 72}. Best is trial 12 with value: 0.5671701261608015.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:21:12,518] Trial 20 finished with value: 0.5651971453445748 and parameters: {'iterations': 961, 'learning_rate': 0.03837183240297397, 'depth': 6, 'colsample_bylevel': 0.5110376445832236, 'min_data_in_leaf': 80}. Best is trial 12 with value: 0.5671701261608015.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:21:23,550] Trial 21 finished with value: 0.5678803534335288 and parameters: {'iterations': 994, 'learning_rate': 0.03252109060809966, 'depth': 6, 'colsample_bylevel': 0.5694296401267871, 'min_data_in_leaf': 82}. Best is trial 21 with value: 0.5678803534335288.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:22:13,627] Trial 22 finished with value: 0.5583705629887585 and parameters: {'iterations': 849, 'learning_rate': 0.03126191382337609, 'depth': 9, 'colsample_bylevel': 0.6257141175250609, 'min_data_in_leaf': 69}. Best is trial 21 with value: 0.5678803534335288.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:22:19,188] Trial 23 finished with value: 0.5491370356793744 and parameters: {'iterations': 928, 'learning_rate': 0.014967004548602303, 'depth': 5, 'colsample_bylevel': 0.2497036771330662, 'min_data_in_leaf': 89}. Best is trial 21 with value: 0.5678803534335288.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:22:24,594] Trial 24 finished with value: 0.5710372372922776 and parameters: {'iterations': 782, 'learning_rate': 0.07239687019887735, 'depth': 4, 'colsample_bylevel': 0.8530916175782312, 'min_data_in_leaf': 54}. Best is trial 24 with value: 0.5710372372922776.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:22:33,938] Trial 25 finished with value: 0.5689655501588466 and parameters: {'iterations': 757, 'learning_rate': 0.0724786826685577, 'depth': 6, 'colsample_bylevel': 0.8418267988795807, 'min_data_in_leaf': 51}. Best is trial 24 with value: 0.5710372372922776.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:22:50,798] Trial 26 finished with value: 0.56636119257087 and parameters: {'iterations': 745, 'learning_rate': 0.07356214065700456, 'depth': 7, 'colsample_bylevel': 0.9312437201802563, 'min_data_in_leaf': 34}. Best is trial 24 with value: 0.5710372372922776.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:22:56,405] Trial 27 finished with value: 0.559110573985826 and parameters: {'iterations': 468, 'learning_rate': 0.08257413064616054, 'depth': 6, 'colsample_bylevel': 0.6596120673541235, 'min_data_in_leaf': 53}. Best is trial 24 with value: 0.5710372372922776.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:23:21,130] Trial 28 finished with value: 0.5532605541300097 and parameters: {'iterations': 632, 'learning_rate': 0.024133675645204796, 'depth': 8, 'colsample_bylevel': 0.8705592417930996, 'min_data_in_leaf': 3}. Best is trial 24 with value: 0.5710372372922776.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:23:26,802] Trial 29 finished with value: 0.5718362429740959 and parameters: {'iterations': 802, 'learning_rate': 0.05678722412985588, 'depth': 4, 'colsample_bylevel': 0.9983570273594571, 'min_data_in_leaf': 44}. Best is trial 29 with value: 0.5718362429740959.
# Best hyperparameters: {'iterations': 802, 'learning_rate': 0.05678722412985588, 'depth': 4, 'colsample_bylevel': 0.9983570273594571, 'min_data_in_leaf': 44}
# Best accuracy: 0.5718362429740959
# [I 2024-03-22 07:23:32,444] A new study created in memory with name: no-name-96d4d9a7-80f5-4e47-af06-7a5bdfa76910
# Tuning catBoost for target: Z_Scratch
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:23:33,025] Trial 0 finished with value: 0.5 and parameters: {'iterations': 147, 'learning_rate': 0.0012776208670579382, 'depth': 2, 'colsample_bylevel': 0.15834735195771082, 'min_data_in_leaf': 82}. Best is trial 0 with value: 0.5.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:24:00,353] Trial 1 finished with value: 0.7680838520853364 and parameters: {'iterations': 388, 'learning_rate': 0.009370012841881386, 'depth': 10, 'colsample_bylevel': 0.8164083365119765, 'min_data_in_leaf': 59}. Best is trial 1 with value: 0.7680838520853364.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:24:19,757] Trial 2 finished with value: 0.7867916516842758 and parameters: {'iterations': 874, 'learning_rate': 0.013132491661405808, 'depth': 7, 'colsample_bylevel': 0.8700355075699263, 'min_data_in_leaf': 64}. Best is trial 2 with value: 0.7867916516842758.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:24:26,750] Trial 3 finished with value: 0.7805770409416677 and parameters: {'iterations': 892, 'learning_rate': 0.05505139109782677, 'depth': 5, 'colsample_bylevel': 0.6714172650618477, 'min_data_in_leaf': 95}. Best is trial 2 with value: 0.7867916516842758.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:24:29,023] Trial 4 finished with value: 0.5662251430446429 and parameters: {'iterations': 389, 'learning_rate': 0.0023204558086393494, 'depth': 3, 'colsample_bylevel': 0.9715877980321708, 'min_data_in_leaf': 33}. Best is trial 2 with value: 0.7867916516842758.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:24:34,099] Trial 5 finished with value: 0.7234218760758632 and parameters: {'iterations': 663, 'learning_rate': 0.0028337094663892118, 'depth': 5, 'colsample_bylevel': 0.5900917936356633, 'min_data_in_leaf': 65}. Best is trial 2 with value: 0.7867916516842758.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:24:40,928] Trial 6 finished with value: 0.7317000189564435 and parameters: {'iterations': 955, 'learning_rate': 0.0028767708899500406, 'depth': 4, 'colsample_bylevel': 0.966239203202699, 'min_data_in_leaf': 85}. Best is trial 2 with value: 0.7867916516842758.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:24:42,391] Trial 7 finished with value: 0.7872955275544232 and parameters: {'iterations': 269, 'learning_rate': 0.09374573794406223, 'depth': 3, 'colsample_bylevel': 0.7278547305731493, 'min_data_in_leaf': 13}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:24:43,715] Trial 8 finished with value: 0.7729787373308478 and parameters: {'iterations': 183, 'learning_rate': 0.05866416993589623, 'depth': 4, 'colsample_bylevel': 0.8777837825693523, 'min_data_in_leaf': 75}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:24:47,371] Trial 9 finished with value: 0.7604855484745164 and parameters: {'iterations': 452, 'learning_rate': 0.01321044615386149, 'depth': 4, 'colsample_bylevel': 0.9831975163439768, 'min_data_in_leaf': 65}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:24:49,274] Trial 10 finished with value: 0.7804010775420548 and parameters: {'iterations': 653, 'learning_rate': 0.09832142881378109, 'depth': 1, 'colsample_bylevel': 0.3556665452527633, 'min_data_in_leaf': 11}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:25:16,751] Trial 11 finished with value: 0.7819607338098796 and parameters: {'iterations': 789, 'learning_rate': 0.017055856144275183, 'depth': 8, 'colsample_bylevel': 0.723564643337853, 'min_data_in_leaf': 37}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:25:22,222] Trial 12 finished with value: 0.7810169494406999 and parameters: {'iterations': 292, 'learning_rate': 0.028003054131213897, 'depth': 7, 'colsample_bylevel': 0.46535860415681096, 'min_data_in_leaf': 6}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:25:42,657] Trial 13 finished with value: 0.7665241958175115 and parameters: {'iterations': 572, 'learning_rate': 0.006147766205439825, 'depth': 8, 'colsample_bylevel': 0.7740855373715, 'min_data_in_leaf': 41}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:25:57,541] Trial 14 finished with value: 0.7843761927470777 and parameters: {'iterations': 806, 'learning_rate': 0.030417958400944238, 'depth': 7, 'colsample_bylevel': 0.48924384855253683, 'min_data_in_leaf': 17}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:26:27,867] Trial 15 finished with value: 0.7631649525111337 and parameters: {'iterations': 535, 'learning_rate': 0.005890620349985086, 'depth': 10, 'colsample_bylevel': 0.6338099720124943, 'min_data_in_leaf': 25}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:26:31,559] Trial 16 finished with value: 0.7833444266780915 and parameters: {'iterations': 294, 'learning_rate': 0.09857245292909576, 'depth': 6, 'colsample_bylevel': 0.843166923222614, 'min_data_in_leaf': 49}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:26:33,735] Trial 17 finished with value: 0.7536790801619544 and parameters: {'iterations': 742, 'learning_rate': 0.02873704944482113, 'depth': 1, 'colsample_bylevel': 0.3679763203371022, 'min_data_in_leaf': 1}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:26:36,973] Trial 18 finished with value: 0.7685877279554838 and parameters: {'iterations': 956, 'learning_rate': 0.04947489087595281, 'depth': 3, 'colsample_bylevel': 0.05467660002331565, 'min_data_in_leaf': 50}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:26:53,742] Trial 19 finished with value: 0.7445451346120008 and parameters: {'iterations': 259, 'learning_rate': 0.006158859814829974, 'depth': 9, 'colsample_bylevel': 0.729334381020468, 'min_data_in_leaf': 27}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:27:00,211] Trial 20 finished with value: 0.7827285547794465 and parameters: {'iterations': 505, 'learning_rate': 0.019863269478067016, 'depth': 6, 'colsample_bylevel': 0.8786662129087068, 'min_data_in_leaf': 100}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:27:15,749] Trial 21 finished with value: 0.7805770409416677 and parameters: {'iterations': 841, 'learning_rate': 0.03229143583266659, 'depth': 7, 'colsample_bylevel': 0.5053007321482411, 'min_data_in_leaf': 22}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:27:29,523] Trial 22 finished with value: 0.7749783020977047 and parameters: {'iterations': 684, 'learning_rate': 0.04117093522075665, 'depth': 7, 'colsample_bylevel': 0.5724335248231605, 'min_data_in_leaf': 13}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:27:50,434] Trial 23 finished with value: 0.777041834235677 and parameters: {'iterations': 870, 'learning_rate': 0.011544985296305776, 'depth': 8, 'colsample_bylevel': 0.3291931460144509, 'min_data_in_leaf': 17}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:27:58,412] Trial 24 finished with value: 0.7829924998788657 and parameters: {'iterations': 774, 'learning_rate': 0.07437264139566763, 'depth': 6, 'colsample_bylevel': 0.42078336415775897, 'min_data_in_leaf': 43}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:28:34,445] Trial 25 finished with value: 0.7736825909292993 and parameters: {'iterations': 986, 'learning_rate': 0.018764202393486647, 'depth': 9, 'colsample_bylevel': 0.2801622932458099, 'min_data_in_leaf': 56}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:28:38,897] Trial 26 finished with value: 0.7833444266780915 and parameters: {'iterations': 604, 'learning_rate': 0.033870994473143734, 'depth': 5, 'colsample_bylevel': 0.5494765283278608, 'min_data_in_leaf': 73}. Best is trial 7 with value: 0.7872955275544232.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:28:54,360] Trial 27 finished with value: 0.7893830740210867 and parameters: {'iterations': 736, 'learning_rate': 0.022923681272539378, 'depth': 7, 'colsample_bylevel': 0.6803981283970291, 'min_data_in_leaf': 31}. Best is trial 27 with value: 0.7893830740210867.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:28:58,099] Trial 28 finished with value: 0.7549747913303598 and parameters: {'iterations': 716, 'learning_rate': 0.008968304723448776, 'depth': 3, 'colsample_bylevel': 0.7077336804654485, 'min_data_in_leaf': 32}. Best is trial 27 with value: 0.7893830740210867.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:28:59,084] Trial 29 finished with value: 0.5 and parameters: {'iterations': 192, 'learning_rate': 0.0010350372209619843, 'depth': 2, 'colsample_bylevel': 0.7911349959272933, 'min_data_in_leaf': 1}. Best is trial 27 with value: 0.7893830740210867.
# Best hyperparameters: {'iterations': 736, 'learning_rate': 0.022923681272539378, 'depth': 7, 'colsample_bylevel': 0.6803981283970291, 'min_data_in_leaf': 31}
# Best accuracy: 0.7893830740210867
# [I 2024-03-22 07:29:14,353] A new study created in memory with name: no-name-64b4b417-4982-43c0-97df-61d6ebcd0c35
# Tuning catBoost for target: K_Scatch
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:29:20,581] Trial 0 finished with value: 0.9452923826977182 and parameters: {'iterations': 112, 'learning_rate': 0.010483307945068068, 'depth': 9, 'colsample_bylevel': 0.6422751869012349, 'min_data_in_leaf': 13}. Best is trial 0 with value: 0.9452923826977182.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:29:21,659] Trial 1 finished with value: 0.9458703059923742 and parameters: {'iterations': 313, 'learning_rate': 0.013843168636461118, 'depth': 2, 'colsample_bylevel': 0.2606045200797125, 'min_data_in_leaf': 65}. Best is trial 1 with value: 0.9458703059923742.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:29:30,957] Trial 2 finished with value: 0.9463104468374447 and parameters: {'iterations': 497, 'learning_rate': 0.011362406585966446, 'depth': 9, 'colsample_bylevel': 0.0891817848639715, 'min_data_in_leaf': 100}. Best is trial 2 with value: 0.9463104468374447.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:29:50,774] Trial 3 finished with value: 0.9454301651473039 and parameters: {'iterations': 428, 'learning_rate': 0.04316251201633543, 'depth': 10, 'colsample_bylevel': 0.5030365821452663, 'min_data_in_leaf': 85}. Best is trial 2 with value: 0.9463104468374447.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:29:57,628] Trial 4 finished with value: 0.9459340958064452 and parameters: {'iterations': 292, 'learning_rate': 0.005181573786645736, 'depth': 8, 'colsample_bylevel': 0.364751010764441, 'min_data_in_leaf': 36}. Best is trial 2 with value: 0.9463104468374447.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:30:29,371] Trial 5 finished with value: 0.9462096607056164 and parameters: {'iterations': 923, 'learning_rate': 0.022123660721876607, 'depth': 8, 'colsample_bylevel': 0.7217334136931409, 'min_data_in_leaf': 70}. Best is trial 2 with value: 0.9463104468374447.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:30:32,495] Trial 6 finished with value: 0.9313086617872931 and parameters: {'iterations': 815, 'learning_rate': 0.00108130626639436, 'depth': 2, 'colsample_bylevel': 0.4508462116981207, 'min_data_in_leaf': 62}. Best is trial 2 with value: 0.9463104468374447.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:30:47,356] Trial 7 finished with value: 0.9467505876825153 and parameters: {'iterations': 227, 'learning_rate': 0.04594533589530887, 'depth': 9, 'colsample_bylevel': 0.8576724972187123, 'min_data_in_leaf': 3}. Best is trial 7 with value: 0.9467505876825153.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:30:50,311] Trial 8 finished with value: 0.9462836533411312 and parameters: {'iterations': 636, 'learning_rate': 0.05071247309031529, 'depth': 4, 'colsample_bylevel': 0.2131762437135657, 'min_data_in_leaf': 46}. Best is trial 7 with value: 0.9467505876825153.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:30:51,921] Trial 9 finished with value: 0.9461458708915457 and parameters: {'iterations': 504, 'learning_rate': 0.017731313152911043, 'depth': 1, 'colsample_bylevel': 0.7074169828128994, 'min_data_in_leaf': 49}. Best is trial 7 with value: 0.9467505876825153.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:30:53,310] Trial 10 finished with value: 0.94891429559011 and parameters: {'iterations': 119, 'learning_rate': 0.06013889196666104, 'depth': 6, 'colsample_bylevel': 0.9938862818709726, 'min_data_in_leaf': 7}. Best is trial 10 with value: 0.94891429559011.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:30:54,762] Trial 11 finished with value: 0.9479064342718273 and parameters: {'iterations': 123, 'learning_rate': 0.09233800958298037, 'depth': 6, 'colsample_bylevel': 0.9664078991955919, 'min_data_in_leaf': 1}. Best is trial 10 with value: 0.94891429559011.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:30:56,454] Trial 12 finished with value: 0.9443853075112639 and parameters: {'iterations': 149, 'learning_rate': 0.0974173967731386, 'depth': 6, 'colsample_bylevel': 0.9967624297157163, 'min_data_in_leaf': 23}. Best is trial 10 with value: 0.94891429559011.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:31:01,937] Trial 13 finished with value: 0.9417444624408414 and parameters: {'iterations': 681, 'learning_rate': 0.0999938706788965, 'depth': 5, 'colsample_bylevel': 0.9992692867931944, 'min_data_in_leaf': 1}. Best is trial 10 with value: 0.94891429559011.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:31:06,617] Trial 14 finished with value: 0.9463742366515155 and parameters: {'iterations': 373, 'learning_rate': 0.0039134746770697814, 'depth': 6, 'colsample_bylevel': 0.8672426645541231, 'min_data_in_leaf': 24}. Best is trial 10 with value: 0.94891429559011.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:31:08,219] Trial 15 finished with value: 0.9463104468374447 and parameters: {'iterations': 218, 'learning_rate': 0.030426206780156385, 'depth': 4, 'colsample_bylevel': 0.8540543687858593, 'min_data_in_leaf': 20}. Best is trial 10 with value: 0.94891429559011.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:31:10,950] Trial 16 finished with value: 0.9483465751168977 and parameters: {'iterations': 127, 'learning_rate': 0.06900360907297728, 'depth': 7, 'colsample_bylevel': 0.9124787895195051, 'min_data_in_leaf': 10}. Best is trial 10 with value: 0.94891429559011.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:31:15,867] Trial 17 finished with value: 0.9461458708915457 and parameters: {'iterations': 244, 'learning_rate': 0.05593476071755152, 'depth': 7, 'colsample_bylevel': 0.6153057447840196, 'min_data_in_leaf': 35}. Best is trial 10 with value: 0.94891429559011.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:31:24,712] Trial 18 finished with value: 0.9467135913647577 and parameters: {'iterations': 401, 'learning_rate': 0.0044598187320085, 'depth': 7, 'colsample_bylevel': 0.7698394223110568, 'min_data_in_leaf': 11}. Best is trial 10 with value: 0.94891429559011.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# ...
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:43:45,452] Trial 0 finished with value: 0.6020451081621548 and parameters: {'iterations': 259, 'learning_rate': 0.01785546878627443, 'depth': 6, 'colsample_bylevel': 0.8837215747618214, 'min_data_in_leaf': 50}. Best is trial 0 with value: 0.6020451081621548.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:44:00,226] Trial 1 finished with value: 0.617414235142156 and parameters: {'iterations': 186, 'learning_rate': 0.02520329890706095, 'depth': 10, 'colsample_bylevel': 0.9366187396126514, 'min_data_in_leaf': 58}. Best is trial 1 with value: 0.617414235142156.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:44:00,634] Trial 2 finished with value: 0.5 and parameters: {'iterations': 127, 'learning_rate': 0.001447459934858467, 'depth': 1, 'colsample_bylevel': 0.3379315063655902, 'min_data_in_leaf': 46}. Best is trial 1 with value: 0.617414235142156.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:44:02,024] Trial 3 finished with value: 0.5667939326348583 and parameters: {'iterations': 341, 'learning_rate': 0.012608170310824295, 'depth': 2, 'colsample_bylevel': 0.6742218464510185, 'min_data_in_leaf': 96}. Best is trial 1 with value: 0.617414235142156.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:44:10,271] Trial 4 finished with value: 0.5780899683867902 and parameters: {'iterations': 888, 'learning_rate': 0.0019275021659363907, 'depth': 6, 'colsample_bylevel': 0.3920083687973244, 'min_data_in_leaf': 100}. Best is trial 1 with value: 0.617414235142156.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:44:12,303] Trial 5 finished with value: 0.5989450658434075 and parameters: {'iterations': 795, 'learning_rate': 0.03588932835388385, 'depth': 1, 'colsample_bylevel': 0.28170440555253, 'min_data_in_leaf': 42}. Best is trial 1 with value: 0.617414235142156.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:44:28,408] Trial 6 finished with value: 0.6176021289693822 and parameters: {'iterations': 811, 'learning_rate': 0.01248353645502038, 'depth': 7, 'colsample_bylevel': 0.60069444369, 'min_data_in_leaf': 100}. Best is trial 6 with value: 0.6176021289693822.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:44:54,090] Trial 7 finished with value: 0.6087540645639653 and parameters: {'iterations': 798, 'learning_rate': 0.004999961451818173, 'depth': 8, 'colsample_bylevel': 0.6370606171396922, 'min_data_in_leaf': 62}. Best is trial 6 with value: 0.6176021289693822.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:44:56,468] Trial 8 finished with value: 0.5620494223690924 and parameters: {'iterations': 335, 'learning_rate': 0.0017219120965079953, 'depth': 5, 'colsample_bylevel': 0.565241747545369, 'min_data_in_leaf': 23}. Best is trial 6 with value: 0.6176021289693822.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:45:26,990] Trial 9 finished with value: 0.5789269339420583 and parameters: {'iterations': 779, 'learning_rate': 0.0011503971982578093, 'depth': 9, 'colsample_bylevel': 0.347173920722642, 'min_data_in_leaf': 44}. Best is trial 6 with value: 0.6176021289693822.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:45:29,182] Trial 10 finished with value: 0.5648660655161958 and parameters: {'iterations': 574, 'learning_rate': 0.0049062570011824715, 'depth': 4, 'colsample_bylevel': 0.08955400610427827, 'min_data_in_leaf': 80}. Best is trial 6 with value: 0.6176021289693822.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:46:14,799] Trial 11 finished with value: 0.6122287771716822 and parameters: {'iterations': 570, 'learning_rate': 0.06087246120473721, 'depth': 10, 'colsample_bylevel': 0.9925065636172844, 'min_data_in_leaf': 11}. Best is trial 6 with value: 0.6176021289693822.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:46:50,801] Trial 12 finished with value: 0.618987544550538 and parameters: {'iterations': 965, 'learning_rate': 0.026174753345106216, 'depth': 8, 'colsample_bylevel': 0.8100664774174455, 'min_data_in_leaf': 73}. Best is trial 12 with value: 0.618987544550538.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:47:27,227] Trial 13 finished with value: 0.6060093444687232 and parameters: {'iterations': 991, 'learning_rate': 0.09725599245840215, 'depth': 8, 'colsample_bylevel': 0.7894887295869556, 'min_data_in_leaf': 80}. Best is trial 12 with value: 0.618987544550538.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:47:49,131] Trial 14 finished with value: 0.6135970794183395 and parameters: {'iterations': 988, 'learning_rate': 0.007867184079748311, 'depth': 7, 'colsample_bylevel': 0.7700273869824598, 'min_data_in_leaf': 81}. Best is trial 12 with value: 0.618987544550538.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:48:10,060] Trial 15 finished with value: 0.6118387578095026 and parameters: {'iterations': 714, 'learning_rate': 0.03524374251537704, 'depth': 8, 'colsample_bylevel': 0.509568417467038, 'min_data_in_leaf': 70}. Best is trial 12 with value: 0.618987544550538.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:48:14,702] Trial 16 finished with value: 0.6046748572300956 and parameters: {'iterations': 896, 'learning_rate': 0.009944848895793246, 'depth': 3, 'colsample_bylevel': 0.7721917972515724, 'min_data_in_leaf': 90}. Best is trial 12 with value: 0.618987544550538.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:49:48,373] Trial 20 finished with value: 0.6165842678233321 and parameters: {'iterations': 905, 'learning_rate': 0.05936308319749548, 'depth': 9, 'colsample_bylevel': 0.8310694916691249, 'min_data_in_leaf': 28}. Best is trial 19 with value: 0.6227254261337908.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:50:07,160] Trial 21 finished with value: 0.6080378332895404 and parameters: {'iterations': 891, 'learning_rate': 0.041147799971951615, 'depth': 7, 'colsample_bylevel': 0.7382951088472605, 'min_data_in_leaf': 27}. Best is trial 19 with value: 0.6227254261337908.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:50:22,422] Trial 22 finished with value: 0.6177524440311629 and parameters: {'iterations': 684, 'learning_rate': 0.02184016980906961, 'depth': 7, 'colsample_bylevel': 0.8795852572090381, 'min_data_in_leaf': 1}. Best is trial 19 with value: 0.6227254261337908.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:51:08,550] Trial 23 finished with value: 0.6167802772524853 and parameters: {'iterations': 703, 'learning_rate': 0.09439400097428284, 'depth': 9, 'colsample_bylevel': 0.8906141791028216, 'min_data_in_leaf': 1}. Best is trial 19 with value: 0.6227254261337908.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:51:14,746] Trial 24 finished with value: 0.613627542329921 and parameters: {'iterations': 482, 'learning_rate': 0.022483226044748582, 'depth': 6, 'colsample_bylevel': 0.9823587392843084, 'min_data_in_leaf': 15}. Best is trial 19 with value: 0.6227254261337908.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:51:37,832] Trial 25 finished with value: 0.6141414128345539 and parameters: {'iterations': 616, 'learning_rate': 0.055571358894745584, 'depth': 8, 'colsample_bylevel': 0.8626061847321758, 'min_data_in_leaf': 36}. Best is trial 19 with value: 0.6227254261337908.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:51:44,875] Trial 26 finished with value: 0.6190302396737198 and parameters: {'iterations': 977, 'learning_rate': 0.028186124401537543, 'depth': 4, 'colsample_bylevel': 0.9374891179618875, 'min_data_in_leaf': 1}. Best is trial 19 with value: 0.6227254261337908.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:51:51,560] Trial 27 finished with value: 0.6159230815011087 and parameters: {'iterations': 948, 'learning_rate': 0.032276608441663385, 'depth': 4, 'colsample_bylevel': 0.9304250613165522, 'min_data_in_leaf': 17}. Best is trial 19 with value: 0.6227254261337908.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:51:57,669] Trial 28 finished with value: 0.6195614587476896 and parameters: {'iterations': 849, 'learning_rate': 0.04875850836558087, 'depth': 4, 'colsample_bylevel': 0.7020667661553357, 'min_data_in_leaf': 36}. Best is trial 19 with value: 0.6227254261337908.
# /tmp/ipykernel_33/4222377827.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# [I 2024-03-22 07:52:02,554] Trial 29 finished with value: 0.6160510492532353 and parameters: {'iterations': 855, 'learning_rate': 0.07014069116601271, 'depth': 3, 'colsample_bylevel': 0.7260014214484902, 'min_data_in_leaf': 34}. Best is trial 19 with value: 0.6227254261337908.
# Best hyperparameters: {'iterations': 909, 'learning_rate': 0.054022829202738445, 'depth': 7, 'colsample_bylevel': 0.8443558887299824, 'min_data_in_leaf': 27}
# Best accuracy: 0.6227254261337908
