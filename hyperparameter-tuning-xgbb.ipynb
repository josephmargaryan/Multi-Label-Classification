# %%
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier 
import optuna
from sklearn.metrics import roc_auc_score
import numpy as np
import pandas as pd
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
import pickle

# %%
train = pd.read_csv("/kaggle/input/playground-series-s4e3/train.csv")
train_original = pd.read_csv("/kaggle/input/original/faults.csv")

train.drop(columns=['id'], axis=1, inplace=True)
target_cols = ['Pastry','Z_Scratch','K_Scatch','Stains','Dirtiness','Bumps','Other_Faults']
train = train[train[target_cols].sum(axis=1) == 1]

# %%
test = pd.concat([train_original, train], axis=0)

# %%
def feature_generator(data):

    "A function to generate additional features"

    epsilon = 1e-6  # A small constant to avoid division by zero or taking the logarithm of zero
    # Location Features
    data['X_Distance'] = data['X_Maximum'] - data['X_Minimum']
    data['Y_Distance'] = data['Y_Maximum'] - data['Y_Minimum']

    # Density Feature
    data['Density'] = data['Pixels_Areas'] / (data['X_Perimeter'] + data['Y_Perimeter'])

    # Relative Perimeter Feature
    data['Relative_Perimeter'] = data['X_Perimeter'] / (data['X_Perimeter'] + data['Y_Perimeter'] + epsilon)

    # Circularity Feature
    data['Circularity'] = data['Pixels_Areas'] / (data['X_Perimeter'] ** 2)

    # Symmetry Index Feature
    data['Symmetry_Index'] = np.abs(data['X_Distance'] - data['Y_Distance']) / (data['X_Distance'] + data['Y_Distance'] + epsilon)
    
    # Color Contrast Feature
    data['Color_Contrast'] = data['Maximum_of_Luminosity'] - data['Minimum_of_Luminosity']

    # Combined Geometric Index Feature
    data['Combined_Geometric_Index'] = data['Edges_Index'] * data['Square_Index']

    # Interaction Term Feature
    data['X_Distance*Pixels_Areas'] = data['X_Distance'] * data['Pixels_Areas']
    
    # Additional Features
    data['sin_orientation'] = np.sin(data['Orientation_Index'])
    data['Edges_Index2'] = np.exp(data['Edges_Index'] + epsilon)
    data['X_Maximum2'] = np.sin(data['X_Maximum'])
    data['Y_Minimum2'] = np.sin(data['Y_Minimum'])
    data['Aspect_Ratio_Pixels'] = np.where(data['Y_Perimeter'] == 0, 0, data['X_Perimeter'] / data['Y_Perimeter'])
    data['Aspect_Ratio'] = np.where(data['Y_Distance'] == 0, 0, data['X_Distance'] / data['Y_Distance'])

    # Average Luminosity Feature
    data['Average_Luminosity'] = (data['Sum_of_Luminosity'] + data['Minimum_of_Luminosity']) / 2
    
    # Normalized Steel Thickness Feature
    data['Normalized_Steel_Thickness'] = (data['Steel_Plate_Thickness'] - data['Steel_Plate_Thickness'].min()) / (data['Steel_Plate_Thickness'].max() - data['Steel_Plate_Thickness'].min())

    # Logarithmic Features
    data['Log_Perimeter'] = np.log(data['X_Perimeter'] + data['Y_Perimeter'] + epsilon)
    data['Log_Luminosity'] = np.log(data['Sum_of_Luminosity'] + epsilon)
    data['Log_Aspect_Ratio'] = np.log(data['Aspect_Ratio'] ** 2 + epsilon)

    # Statistical Features
    data['Combined_Index'] = data['Orientation_Index'] * data['Luminosity_Index']
    data['Sigmoid_Areas'] = 1 / (1 + np.exp(-data['LogOfAreas'] + epsilon))

    return data

test = feature_generator(test)

# %%
# Initialize the scaler
scaler = RobustScaler()

# Identify discrete features
discrete_features = ['TypeOfSteel_A300', 'TypeOfSteel_A400']

# Identify continuous features
continuous_features = [col for col in test.columns if col not in discrete_features + target_cols]

# Fit and transform the scaler on training data
test[continuous_features] = scaler.fit_transform(test[continuous_features])

# %%
X = test.drop(columns=target_cols, axis=1)
y1 = test['Pastry']
y2 = test['Z_Scratch']
y3 = test['K_Scatch']
y4 = test['Stains']
y5 = test['Dirtiness']
y6 = test['Bumps']
y7 = test['Other_Faults']

# %%
X_train_Pastry, X_test_pastry, y_train_Pastry, y_test_pastry = train_test_split(X, y1, test_size=0.3, random_state=24)
X_train_Z_Scratch, X_test_Z_Scratch, y_train_Z_Scratch, y_test_Z_Scratch = train_test_split(X, y2, test_size=0.3, random_state=24)
X_train_K_Scatch, X_test_K_Scatch, y_train_K_Scatch, y_test_K_Scatch = train_test_split(X, y3, test_size=0.3, random_state=24)
X_train_Stains, X_test_Stains, y_train_Stains, y_test_Stains = train_test_split(X, y4, test_size=0.3, random_state=24)
X_train_Dirtiness, X_test_Dirtiness, y_train_Dirtiness, y_test_Dirtiness = train_test_split(X, y5, test_size=0.3, random_state=24)
X_train_Bumps, X_test_Bumps, y_train_Bumps, y_test_Bumps = train_test_split(X, y6, test_size=0.3, random_state=24)
X_train_Other_Faults, X_test_Other_Faults, y_train_Other_Faults, y_test_Other_Faults = train_test_split(X, y7, test_size=0.3, random_state=24)

# %%
# Assuming target_splits is the dictionary containing splits for each target
target_splits = {
    'Pastry': (X_train_Pastry, X_test_pastry, y_train_Pastry, y_test_pastry),
    'Z_Scratch': (X_train_Z_Scratch, X_test_Z_Scratch, y_train_Z_Scratch, y_test_Z_Scratch),
    'K_Scatch': (X_train_K_Scatch, X_test_K_Scatch, y_train_K_Scatch, y_test_K_Scatch),
    'Stains': (X_train_Stains, X_test_Stains, y_train_Stains, y_test_Stains),
    'Dirtiness': (X_train_Dirtiness, X_test_Dirtiness, y_train_Dirtiness, y_test_Dirtiness),
    'Bumps': (X_train_Bumps, X_test_Bumps, y_train_Bumps, y_test_Bumps),
    'Other_Faults': (X_train_Other_Faults, X_test_Other_Faults, y_train_Other_Faults, y_test_Other_Faults)
}

# %%
# Define the objective function for XGBoost
def objective_xgb(trial, X_train, X_test, y_train, y_test):
    params = {
        "objective": "binary:logistic",
        "n_estimators": 1000,
        "verbosity": 0,
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "max_depth": trial.suggest_int("max_depth", 1, 10),
        "subsample": trial.suggest_float("subsample", 0.05, 1.0),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 20),
        "eval_metric": 'auc',
    }

    model_xgb = XGBClassifier(**params)
    model_xgb.fit(X_train, y_train, verbose=False)
    predictions_xgb = model_xgb.predict(X_test)
    accuracy_xgb = roc_auc_score(y_test, predictions_xgb)
    return accuracy_xgb

# Dictionary to store best models for each target
best_models = {}

# Loop over each target
for target, (X_train, X_test, y_train, y_test) in target_splits.items():
    print(f"Tuning XGBoost for target: {target}")
    study_xgb = optuna.create_study(direction='maximize')
    study_xgb.optimize(lambda trial: objective_xgb(trial, X_train, X_test, y_train, y_test), n_trials=30)
    print('Best hyperparameters:', study_xgb.best_params)
    print('Best accuracy:', study_xgb.best_value)

    # Define the best hyperparameters obtained from Optuna
    best_params_xgb = study_xgb.best_params

    # Instantiate XGBClassifier with the best hyperparameters
    best_xgb_model = XGBClassifier(**best_params_xgb, silent=True)

    # Fit the model on the training data
    best_xgb_model.fit(X_train, y_train)

    # Save the model to a file
    model_filename = f"best_xmodel_{target}.pkl"
    with open(model_filename, 'wb') as f:
        pickle.dump(best_xgb_model, f)

    # Store the model in the dictionary
    best_models[target] = best_xgb_model
# Out:
# [I 2024-03-22 07:19:03,682] A new study created in memory with name: no-name-99d032cd-9e15-4926-8f3e-2ae5adac33a3
# Tuning XGBoost for target: Pastry
# [I 2024-03-22 07:19:07,197] Trial 0 finished with value: 0.5280755513807429 and parameters: {'learning_rate': 0.004125116120145079, 'max_depth': 7, 'subsample': 0.1362532293324489, 'min_child_weight': 20}. Best is trial 0 with value: 0.5280755513807429.
# [I 2024-03-22 07:19:13,413] Trial 1 finished with value: 0.5291408922898337 and parameters: {'learning_rate': 0.0024678343302905236, 'max_depth': 7, 'subsample': 0.9078645676541163, 'min_child_weight': 18}. Best is trial 1 with value: 0.5291408922898337.
# [I 2024-03-22 07:19:16,850] Trial 2 finished with value: 0.577932742240958 and parameters: {'learning_rate': 0.03458306058458436, 'max_depth': 4, 'subsample': 0.7276464219661168, 'min_child_weight': 18}. Best is trial 2 with value: 0.577932742240958.
# [I 2024-03-22 07:19:19,679] Trial 3 finished with value: 0.5366876298264908 and parameters: {'learning_rate': 0.011481501755318934, 'max_depth': 8, 'subsample': 0.08283174143624582, 'min_child_weight': 18}. Best is trial 2 with value: 0.577932742240958.
# [I 2024-03-22 07:19:23,832] Trial 4 finished with value: 0.5085133721285434 and parameters: {'learning_rate': 0.001875214748092988, 'max_depth': 4, 'subsample': 0.9586702032830118, 'min_child_weight': 9}. Best is trial 2 with value: 0.577932742240958.
# [I 2024-03-22 07:19:28,391] Trial 5 finished with value: 0.5606198069403714 and parameters: {'learning_rate': 0.011106135134243383, 'max_depth': 4, 'subsample': 0.6703535315943955, 'min_child_weight': 5}. Best is trial 2 with value: 0.577932742240958.
# [I 2024-03-22 07:19:34,153] Trial 6 finished with value: 0.5786528974217986 and parameters: {'learning_rate': 0.023788989326347224, 'max_depth': 10, 'subsample': 0.19517468502693108, 'min_child_weight': 6}. Best is trial 6 with value: 0.5786528974217986.
# [I 2024-03-22 07:19:38,256] Trial 7 finished with value: 0.5360562530547409 and parameters: {'learning_rate': 0.004054078081875216, 'max_depth': 8, 'subsample': 0.13935914668577376, 'min_child_weight': 12}. Best is trial 6 with value: 0.5786528974217986.
# [I 2024-03-22 07:19:43,694] Trial 8 finished with value: 0.562859122983871 and parameters: {'learning_rate': 0.007708333820117379, 'max_depth': 7, 'subsample': 0.9045406186613599, 'min_child_weight': 19}. Best is trial 6 with value: 0.5786528974217986.
# [I 2024-03-22 07:19:46,122] Trial 9 finished with value: 0.5 and parameters: {'learning_rate': 0.0017023914952781286, 'max_depth': 2, 'subsample': 0.5738417680432524, 'min_child_weight': 1}. Best is trial 6 with value: 0.5786528974217986.
# [I 2024-03-22 07:19:51,304] Trial 10 finished with value: 0.5889914772727273 and parameters: {'learning_rate': 0.09750067167281769, 'max_depth': 10, 'subsample': 0.3632265551724956, 'min_child_weight': 11}. Best is trial 10 with value: 0.5889914772727273.
# [I 2024-03-22 07:19:56,406] Trial 11 finished with value: 0.5831712411412512 and parameters: {'learning_rate': 0.08929774434274373, 'max_depth': 10, 'subsample': 0.3450862456713544, 'min_child_weight': 11}. Best is trial 10 with value: 0.5889914772727273.
# [I 2024-03-22 07:20:02,289] Trial 12 finished with value: 0.5937463724951123 and parameters: {'learning_rate': 0.07625559206822985, 'max_depth': 10, 'subsample': 0.3548720042302418, 'min_child_weight': 13}. Best is trial 12 with value: 0.5937463724951123.
# [I 2024-03-22 07:20:07,193] Trial 13 finished with value: 0.5877386516373411 and parameters: {'learning_rate': 0.09179865079356017, 'max_depth': 10, 'subsample': 0.3814976717473476, 'min_child_weight': 14}. Best is trial 12 with value: 0.5937463724951123.
# [I 2024-03-22 07:20:12,280] Trial 14 finished with value: 0.5843154325513196 and parameters: {'learning_rate': 0.04544659083838116, 'max_depth': 9, 'subsample': 0.3709810084793099, 'min_child_weight': 15}. Best is trial 12 with value: 0.5937463724951123.
# [I 2024-03-22 07:20:13,927] Trial 15 finished with value: 0.5498671187683284 and parameters: {'learning_rate': 0.056390446399969985, 'max_depth': 1, 'subsample': 0.265878053135577, 'min_child_weight': 8}. Best is trial 12 with value: 0.5937463724951123.
# [I 2024-03-22 07:20:18,599] Trial 16 finished with value: 0.5781990774682306 and parameters: {'learning_rate': 0.0221640956719255, 'max_depth': 6, 'subsample': 0.5295244851110248, 'min_child_weight': 15}. Best is trial 12 with value: 0.5937463724951123.
# [I 2024-03-22 07:20:23,789] Trial 17 finished with value: 0.5876399453201369 and parameters: {'learning_rate': 0.09801964432496811, 'max_depth': 9, 'subsample': 0.4508277167244142, 'min_child_weight': 13}. Best is trial 12 with value: 0.5937463724951123.
# [I 2024-03-22 07:20:30,047] Trial 18 finished with value: 0.5849170255987293 and parameters: {'learning_rate': 0.021666305686217583, 'max_depth': 9, 'subsample': 0.2731739559049881, 'min_child_weight': 10}. Best is trial 12 with value: 0.5937463724951123.
# [I 2024-03-22 07:20:34,448] Trial 19 finished with value: 0.5796592436461387 and parameters: {'learning_rate': 0.05541535165457785, 'max_depth': 5, 'subsample': 0.6207670231418886, 'min_child_weight': 7}. Best is trial 12 with value: 0.5937463724951123.
# [I 2024-03-22 07:20:42,217] Trial 20 finished with value: 0.576591138196481 and parameters: {'learning_rate': 0.03264977760255599, 'max_depth': 8, 'subsample': 0.4655878350896062, 'min_child_weight': 2}. Best is trial 12 with value: 0.5937463724951123.
# [I 2024-03-22 07:20:47,241] Trial 21 finished with value: 0.5939239293132942 and parameters: {'learning_rate': 0.07237673586512304, 'max_depth': 10, 'subsample': 0.36163904642587036, 'min_child_weight': 14}. Best is trial 21 with value: 0.5939239293132942.
# [I 2024-03-22 07:20:51,639] Trial 22 finished with value: 0.5938252229960899 and parameters: {'learning_rate': 0.06303899728819208, 'max_depth': 10, 'subsample': 0.2596612792108018, 'min_child_weight': 16}. Best is trial 21 with value: 0.5939239293132942.
# [I 2024-03-22 07:20:55,969] Trial 23 finished with value: 0.5928288046798632 and parameters: {'learning_rate': 0.05912100194428604, 'max_depth': 9, 'subsample': 0.25958985498312503, 'min_child_weight': 16}. Best is trial 21 with value: 0.5939239293132942.
# [I 2024-03-22 07:21:00,976] Trial 24 finished with value: 0.5788304542399805 and parameters: {'learning_rate': 0.03723089287323784, 'max_depth': 10, 'subsample': 0.2098630634415942, 'min_child_weight': 16}. Best is trial 21 with value: 0.5939239293132942.
# [I 2024-03-22 07:21:06,350] Trial 25 finished with value: 0.5795803931451613 and parameters: {'learning_rate': 0.06401495736959373, 'max_depth': 9, 'subsample': 0.44017058599026054, 'min_child_weight': 13}. Best is trial 21 with value: 0.5939239293132942.
# [I 2024-03-22 07:21:11,169] Trial 26 finished with value: 0.5753283846529815 and parameters: {'learning_rate': 0.016791773436212604, 'max_depth': 8, 'subsample': 0.3121532574757568, 'min_child_weight': 16}. Best is trial 21 with value: 0.5939239293132942.
# [I 2024-03-22 07:21:13,862] Trial 27 finished with value: 0.5663711204789833 and parameters: {'learning_rate': 0.0701603781619843, 'max_depth': 6, 'subsample': 0.06013912182013759, 'min_child_weight': 13}. Best is trial 21 with value: 0.5939239293132942.
# [I 2024-03-22 07:21:19,426] Trial 28 finished with value: 0.5849368814149559 and parameters: {'learning_rate': 0.034640212447803985, 'max_depth': 10, 'subsample': 0.4979298051480219, 'min_child_weight': 17}. Best is trial 21 with value: 0.5939239293132942.
# [I 2024-03-22 07:21:23,060] Trial 29 finished with value: 0.5396471010508308 and parameters: {'learning_rate': 0.005681513776494248, 'max_depth': 8, 'subsample': 0.16730325070855478, 'min_child_weight': 20}. Best is trial 21 with value: 0.5939239293132942.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [07:21:23] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best hyperparameters: {'learning_rate': 0.07237673586512304, 'max_depth': 10, 'subsample': 0.36163904642587036, 'min_child_weight': 14}
# Best accuracy: 0.5939239293132942
# [I 2024-03-22 07:21:23,655] A new study created in memory with name: no-name-5782335d-d8e7-49f0-abda-241a6c917e4e
# Tuning XGBoost for target: Z_Scratch
# [I 2024-03-22 07:21:27,707] Trial 0 finished with value: 0.7682358011562581 and parameters: {'learning_rate': 0.018413402851699887, 'max_depth': 5, 'subsample': 0.41987642834499844, 'min_child_weight': 13}. Best is trial 0 with value: 0.7682358011562581.
# [I 2024-03-22 07:21:31,177] Trial 1 finished with value: 0.760221603375097 and parameters: {'learning_rate': 0.0612320049181548, 'max_depth': 7, 'subsample': 0.22170396738243958, 'min_child_weight': 17}. Best is trial 0 with value: 0.7682358011562581.
# [I 2024-03-22 07:21:36,396] Trial 2 finished with value: 0.753391120733844 and parameters: {'learning_rate': 0.09667678170167153, 'max_depth': 7, 'subsample': 0.5582092042635219, 'min_child_weight': 7}. Best is trial 0 with value: 0.7682358011562581.
# [I 2024-03-22 07:21:41,902] Trial 3 finished with value: 0.7819367194811884 and parameters: {'learning_rate': 0.020338390121824063, 'max_depth': 7, 'subsample': 0.8621380113341255, 'min_child_weight': 9}. Best is trial 3 with value: 0.7819367194811884.
# [I 2024-03-22 07:21:46,771] Trial 4 finished with value: 0.6894535018841683 and parameters: {'learning_rate': 0.0014752320811098718, 'max_depth': 6, 'subsample': 0.34428752498722015, 'min_child_weight': 12}. Best is trial 3 with value: 0.7819367194811884.
# [I 2024-03-22 07:21:52,357] Trial 5 finished with value: 0.7738585543289122 and parameters: {'learning_rate': 0.0029397320580006343, 'max_depth': 6, 'subsample': 0.7855203109653387, 'min_child_weight': 12}. Best is trial 3 with value: 0.7819367194811884.
# [I 2024-03-22 07:21:58,428] Trial 6 finished with value: 0.7652284846491061 and parameters: {'learning_rate': 0.002845953347810481, 'max_depth': 8, 'subsample': 0.8108678877693065, 'min_child_weight': 15}. Best is trial 3 with value: 0.7819367194811884.
# [I 2024-03-22 07:22:00,860] Trial 7 finished with value: 0.6568448062319946 and parameters: {'learning_rate': 0.007871412167292723, 'max_depth': 4, 'subsample': 0.060695737197126814, 'min_child_weight': 17}. Best is trial 3 with value: 0.7819367194811884.
# [I 2024-03-22 07:22:04,657] Trial 8 finished with value: 0.7740105033998337 and parameters: {'learning_rate': 0.06740679927074984, 'max_depth': 3, 'subsample': 0.754056834916613, 'min_child_weight': 3}. Best is trial 3 with value: 0.7819367194811884.
# [I 2024-03-22 07:22:06,319] Trial 9 finished with value: 0.5 and parameters: {'learning_rate': 0.0021543892131539195, 'max_depth': 1, 'subsample': 0.17839485976311703, 'min_child_weight': 11}. Best is trial 3 with value: 0.7819367194811884.
# [I 2024-03-22 07:22:13,434] Trial 10 finished with value: 0.786855619055391 and parameters: {'learning_rate': 0.016279662627383163, 'max_depth': 10, 'subsample': 0.9856999524005242, 'min_child_weight': 7}. Best is trial 10 with value: 0.786855619055391.
# [I 2024-03-22 07:22:20,415] Trial 11 finished with value: 0.7872075458546168 and parameters: {'learning_rate': 0.019205231488083077, 'max_depth': 10, 'subsample': 0.9647491796922689, 'min_child_weight': 7}. Best is trial 11 with value: 0.7872075458546168.
# [I 2024-03-22 07:22:28,377] Trial 12 finished with value: 0.7860877980858242 and parameters: {'learning_rate': 0.009847414902043768, 'max_depth': 10, 'subsample': 0.9725440169713133, 'min_child_weight': 5}. Best is trial 11 with value: 0.7872075458546168.
# [I 2024-03-22 07:22:38,774] Trial 13 finished with value: 0.7779856186048567 and parameters: {'learning_rate': 0.026503238013992996, 'max_depth': 10, 'subsample': 0.9661585563962702, 'min_child_weight': 1}. Best is trial 11 with value: 0.7872075458546168.
# [I 2024-03-22 07:22:45,388] Trial 14 finished with value: 0.7802251141424419 and parameters: {'learning_rate': 0.005603123858761721, 'max_depth': 9, 'subsample': 0.6448134947732822, 'min_child_weight': 8}. Best is trial 11 with value: 0.7872075458546168.
# [I 2024-03-22 07:22:51,807] Trial 15 finished with value: 0.7773697467062116 and parameters: {'learning_rate': 0.03040692188765509, 'max_depth': 9, 'subsample': 0.664805885893921, 'min_child_weight': 5}. Best is trial 11 with value: 0.7872075458546168.
# [I 2024-03-22 07:22:59,295] Trial 16 finished with value: 0.7858238529864049 and parameters: {'learning_rate': 0.013382141740561711, 'max_depth': 10, 'subsample': 0.9864969562938709, 'min_child_weight': 6}. Best is trial 11 with value: 0.7872075458546168.
# [I 2024-03-22 07:23:06,672] Trial 17 finished with value: 0.7849680503170315 and parameters: {'learning_rate': 0.005543240737221418, 'max_depth': 8, 'subsample': 0.878857837152724, 'min_child_weight': 9}. Best is trial 11 with value: 0.7872075458546168.
# [I 2024-03-22 07:23:11,374] Trial 18 finished with value: 0.7655563971196406 and parameters: {'learning_rate': 0.04109265083033826, 'max_depth': 9, 'subsample': 0.6856310162044598, 'min_child_weight': 20}. Best is trial 11 with value: 0.7872075458546168.
# [I 2024-03-22 07:23:13,702] Trial 19 finished with value: 0.7791053663736492 and parameters: {'learning_rate': 0.01691839291015984, 'max_depth': 2, 'subsample': 0.5049937978999717, 'min_child_weight': 3}. Best is trial 11 with value: 0.7872075458546168.
# [I 2024-03-22 07:23:21,821] Trial 20 finished with value: 0.7886792204226352 and parameters: {'learning_rate': 0.006472881288202934, 'max_depth': 8, 'subsample': 0.9262355470560131, 'min_child_weight': 3}. Best is trial 20 with value: 0.7886792204226352.
# [I 2024-03-22 07:23:29,728] Trial 21 finished with value: 0.7885032570230223 and parameters: {'learning_rate': 0.007026859027550603, 'max_depth': 8, 'subsample': 0.8940277652638335, 'min_child_weight': 3}. Best is trial 20 with value: 0.7886792204226352.
# [I 2024-03-22 07:23:40,812] Trial 22 finished with value: 0.7902388766904599 and parameters: {'learning_rate': 0.004858940512730382, 'max_depth': 8, 'subsample': 0.8977095596627609, 'min_child_weight': 1}. Best is trial 22 with value: 0.7902388766904599.
# [I 2024-03-22 07:23:50,102] Trial 23 finished with value: 0.783848302548239 and parameters: {'learning_rate': 0.004274698863214201, 'max_depth': 8, 'subsample': 0.8819365599343706, 'min_child_weight': 2}. Best is trial 22 with value: 0.7902388766904599.
# [I 2024-03-22 07:23:55,217] Trial 24 finished with value: 0.7901508949906536 and parameters: {'learning_rate': 0.007419293030284113, 'max_depth': 5, 'subsample': 0.7336413976316398, 'min_child_weight': 1}. Best is trial 22 with value: 0.7902388766904599.
# [I 2024-03-22 07:24:00,680] Trial 25 finished with value: 0.6693620094170172 and parameters: {'learning_rate': 0.0010199738687221612, 'max_depth': 5, 'subsample': 0.7457783737031247, 'min_child_weight': 1}. Best is trial 22 with value: 0.7902388766904599.
# [I 2024-03-22 07:24:04,777] Trial 26 finished with value: 0.7641087368803134 and parameters: {'learning_rate': 0.003953670097605456, 'max_depth': 4, 'subsample': 0.8218267349762006, 'min_child_weight': 4}. Best is trial 22 with value: 0.7902388766904599.
# [I 2024-03-22 07:24:11,946] Trial 27 finished with value: 0.7730667190306543 and parameters: {'learning_rate': 0.011297656147530151, 'max_depth': 6, 'subsample': 0.5631708062190174, 'min_child_weight': 1}. Best is trial 22 with value: 0.7902388766904599.
# [I 2024-03-22 07:24:15,807] Trial 28 finished with value: 0.7885032570230223 and parameters: {'learning_rate': 0.007539599659980922, 'max_depth': 4, 'subsample': 0.7177393397330202, 'min_child_weight': 4}. Best is trial 22 with value: 0.7902388766904599.
# [I 2024-03-22 07:24:20,974] Trial 29 finished with value: 0.7756581413674651 and parameters: {'learning_rate': 0.004413322636063026, 'max_depth': 5, 'subsample': 0.640629780544812, 'min_child_weight': 2}. Best is trial 22 with value: 0.7902388766904599.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [07:24:21] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best hyperparameters: {'learning_rate': 0.004858940512730382, 'max_depth': 8, 'subsample': 0.8977095596627609, 'min_child_weight': 1}
# Best accuracy: 0.7902388766904599
# [I 2024-03-22 07:24:22,148] A new study created in memory with name: no-name-b960f257-b214-4dc9-bdd5-c7d73e45a4a4
# Tuning XGBoost for target: K_Scatch
# [I 2024-03-22 07:24:25,646] Trial 0 finished with value: 0.9395335553940454 and parameters: {'learning_rate': 0.004014226223959587, 'max_depth': 8, 'subsample': 0.1020491225112092, 'min_child_weight': 8}. Best is trial 0 with value: 0.9395335553940454.
# [I 2024-03-22 07:24:29,651] Trial 1 finished with value: 0.9405988186729731 and parameters: {'learning_rate': 0.06572350107926127, 'max_depth': 5, 'subsample': 0.6820744097497977, 'min_child_weight': 11}. Best is trial 1 with value: 0.9405988186729731.
# [I 2024-03-22 07:24:33,139] Trial 2 finished with value: 0.9255128381658628 and parameters: {'learning_rate': 0.0012004244780604095, 'max_depth': 9, 'subsample': 0.22102203340111798, 'min_child_weight': 20}. Best is trial 1 with value: 0.9405988186729731.
# [I 2024-03-22 07:24:40,708] Trial 3 finished with value: 0.9459073023101316 and parameters: {'learning_rate': 0.006837855453286933, 'max_depth': 9, 'subsample': 0.8291868808367941, 'min_child_weight': 6}. Best is trial 3 with value: 0.9459073023101316.
# [I 2024-03-22 07:24:43,586] Trial 4 finished with value: 0.9460348819382735 and parameters: {'learning_rate': 0.003020354689957147, 'max_depth': 3, 'subsample': 0.18134681628424737, 'min_child_weight': 5}. Best is trial 4 with value: 0.9460348819382735.
# [I 2024-03-22 07:24:45,822] Trial 5 finished with value: 0.9464852256047876 and parameters: {'learning_rate': 0.09408047507790439, 'max_depth': 2, 'subsample': 0.7156748111211515, 'min_child_weight': 17}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:24:47,537] Trial 6 finished with value: 0.9361132147653104 and parameters: {'learning_rate': 0.004662356493637738, 'max_depth': 1, 'subsample': 0.6776787742934368, 'min_child_weight': 11}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:24:50,650] Trial 7 finished with value: 0.9435956091315075 and parameters: {'learning_rate': 0.002394619616781276, 'max_depth': 3, 'subsample': 0.9321651405476048, 'min_child_weight': 3}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:24:53,461] Trial 8 finished with value: 0.9426247441309822 and parameters: {'learning_rate': 0.05557709204109395, 'max_depth': 7, 'subsample': 0.15460123702934925, 'min_child_weight': 15}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:24:56,256] Trial 9 finished with value: 0.9430278886582952 and parameters: {'learning_rate': 0.05595538542321701, 'max_depth': 3, 'subsample': 0.7786376086921308, 'min_child_weight': 4}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:24:57,932] Trial 10 finished with value: 0.9435688156351939 and parameters: {'learning_rate': 0.018861292421341526, 'max_depth': 1, 'subsample': 0.4228667640046544, 'min_child_weight': 20}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:01,424] Trial 11 finished with value: 0.9461088745737882 and parameters: {'learning_rate': 0.017027525304758477, 'max_depth': 4, 'subsample': 0.39363532867884654, 'min_child_weight': 15}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:05,284] Trial 12 finished with value: 0.9463844394729595 and parameters: {'learning_rate': 0.01859139984154045, 'max_depth': 5, 'subsample': 0.4476030090290705, 'min_child_weight': 15}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:09,513] Trial 13 finished with value: 0.9442845213794357 and parameters: {'learning_rate': 0.022676558517369497, 'max_depth': 6, 'subsample': 0.531356432023269, 'min_child_weight': 16}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:14,171] Trial 14 finished with value: 0.9438443805343651 and parameters: {'learning_rate': 0.030475890348433888, 'max_depth': 5, 'subsample': 0.5390067113516965, 'min_child_weight': 17}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:16,505] Trial 15 finished with value: 0.9464750227833438 and parameters: {'learning_rate': 0.00984765519096131, 'max_depth': 2, 'subsample': 0.3468093734191111, 'min_child_weight': 13}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:18,738] Trial 16 finished with value: 0.9452285928836474 and parameters: {'learning_rate': 0.09871366443068269, 'max_depth': 2, 'subsample': 0.302789984909913, 'min_child_weight': 13}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:21,133] Trial 17 finished with value: 0.9460348819382735 and parameters: {'learning_rate': 0.008794361139842681, 'max_depth': 2, 'subsample': 0.6308833407265855, 'min_child_weight': 18}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:22,821] Trial 18 finished with value: 0.9455309512791321 and parameters: {'learning_rate': 0.010891248398598688, 'max_depth': 1, 'subsample': 0.9632085161289774, 'min_child_weight': 1}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:26,195] Trial 19 finished with value: 0.9426247441309822 and parameters: {'learning_rate': 0.03021756380866958, 'max_depth': 4, 'subsample': 0.2867316423356383, 'min_child_weight': 13}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:28,410] Trial 20 finished with value: 0.9317755961286769 and parameters: {'learning_rate': 0.0014668302400228906, 'max_depth': 2, 'subsample': 0.8029831026863714, 'min_child_weight': 8}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:32,757] Trial 21 finished with value: 0.9448892381704052 and parameters: {'learning_rate': 0.013519573550625238, 'max_depth': 6, 'subsample': 0.45274532406609314, 'min_child_weight': 13}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:36,149] Trial 22 finished with value: 0.9438443805343651 and parameters: {'learning_rate': 0.03600875579973702, 'max_depth': 4, 'subsample': 0.5902534741686902, 'min_child_weight': 18}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:40,461] Trial 23 finished with value: 0.9454301651473039 and parameters: {'learning_rate': 0.006641147132698754, 'max_depth': 10, 'subsample': 0.3437443143381251, 'min_child_weight': 15}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:45,808] Trial 24 finished with value: 0.9394799684014185 and parameters: {'learning_rate': 0.07789213101576159, 'max_depth': 7, 'subsample': 0.4458076802445946, 'min_child_weight': 9}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:47,908] Trial 25 finished with value: 0.9362242037185825 and parameters: {'learning_rate': 0.03978983028788616, 'max_depth': 2, 'subsample': 0.05540973817408901, 'min_child_weight': 13}. Best is trial 5 with value: 0.9464852256047876.
# [I 2024-03-22 07:25:50,850] Trial 26 finished with value: 0.9466128052329295 and parameters: {'learning_rate': 0.012013990509665324, 'max_depth': 3, 'subsample': 0.7311337362865397, 'min_child_weight': 18}. Best is trial 26 with value: 0.9466128052329295.
# [I 2024-03-22 07:25:53,708] Trial 27 finished with value: 0.9420366180148824 and parameters: {'learning_rate': 0.0019733474919634768, 'max_depth': 3, 'subsample': 0.7335407412223903, 'min_child_weight': 18}. Best is trial 26 with value: 0.9466128052329295.
# [I 2024-03-22 07:25:55,361] Trial 28 finished with value: 0.9365163592926234 and parameters: {'learning_rate': 0.005532260978479336, 'max_depth': 1, 'subsample': 0.8684080104241417, 'min_child_weight': 19}. Best is trial 26 with value: 0.9466128052329295.
# [I 2024-03-22 07:25:58,895] Trial 29 finished with value: 0.9472915146594137 and parameters: {'learning_rate': 0.0034113578507053064, 'max_depth': 4, 'subsample': 0.7211187069711512, 'min_child_weight': 16}. Best is trial 29 with value: 0.9472915146594137.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [07:25:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best hyperparameters: {'learning_rate': 0.0034113578507053064, 'max_depth': 4, 'subsample': 0.7211187069711512, 'min_child_weight': 16}
# Best accuracy: 0.9472915146594137
# [I 2024-03-22 07:25:59,299] A new study created in memory with name: no-name-6ac67e5a-0be0-4c05-a109-8d38c7c835cc
# Tuning XGBoost for target: Stains
# [I 2024-03-22 07:26:02,582] Trial 0 finished with value: 0.8790982003663663 and parameters: {'learning_rate': 0.005426838963096274, 'max_depth': 5, 'subsample': 0.6887156476828166, 'min_child_weight': 20}. Best is trial 0 with value: 0.8790982003663663.
# [I 2024-03-22 07:26:04,939] Trial 1 finished with value: 0.8790136123101999 and parameters: {'learning_rate': 0.015412276599219437, 'max_depth': 2, 'subsample': 0.4855074208062172, 'min_child_weight': 1}. Best is trial 0 with value: 0.8790982003663663.
# [I 2024-03-22 07:26:11,559] Trial 2 finished with value: 0.8708645081250012 and parameters: {'learning_rate': 0.0032114765323886193, 'max_depth': 10, 'subsample': 0.7325533078918277, 'min_child_weight': 1}. Best is trial 0 with value: 0.8790982003663663.
# [I 2024-03-22 07:26:15,586] Trial 3 finished with value: 0.8314723960976709 and parameters: {'learning_rate': 0.001757739719109201, 'max_depth': 9, 'subsample': 0.5544594256776342, 'min_child_weight': 13}. Best is trial 0 with value: 0.8790982003663663.
# [I 2024-03-22 07:26:18,551] Trial 4 finished with value: 0.8575082359661138 and parameters: {'learning_rate': 0.022829766563014282, 'max_depth': 5, 'subsample': 0.18285669701673352, 'min_child_weight': 5}. Best is trial 0 with value: 0.8790982003663663.
# [I 2024-03-22 07:26:21,553] Trial 5 finished with value: 0.8627999919959689 and parameters: {'learning_rate': 0.012434787255523678, 'max_depth': 7, 'subsample': 0.36847864934803953, 'min_child_weight': 12}. Best is trial 0 with value: 0.8790982003663663.
# [I 2024-03-22 07:26:25,060] Trial 6 finished with value: 0.865911104319812 and parameters: {'learning_rate': 0.0031294461837629716, 'max_depth': 9, 'subsample': 0.9525191579741088, 'min_child_weight': 20}. Best is trial 0 with value: 0.8790982003663663.
# [I 2024-03-22 07:26:26,673] Trial 7 finished with value: 0.8791827884225327 and parameters: {'learning_rate': 0.024213744844226313, 'max_depth': 1, 'subsample': 0.9925972912671301, 'min_child_weight': 19}. Best is trial 7 with value: 0.8791827884225327.
# [I 2024-03-22 07:26:30,392] Trial 8 finished with value: 0.8734680921118453 and parameters: {'learning_rate': 0.012938806135618654, 'max_depth': 7, 'subsample': 0.5308780883950615, 'min_child_weight': 8}. Best is trial 7 with value: 0.8791827884225327.
# [I 2024-03-22 07:26:33,100] Trial 9 finished with value: 0.8658265162636455 and parameters: {'learning_rate': 0.003728006565110378, 'max_depth': 3, 'subsample': 0.435522976538604, 'min_child_weight': 13}. Best is trial 7 with value: 0.8791827884225327.
# [I 2024-03-22 07:26:34,736] Trial 10 finished with value: 0.8870781284392321 and parameters: {'learning_rate': 0.08607504056403618, 'max_depth': 1, 'subsample': 0.9717714142631431, 'min_child_weight': 16}. Best is trial 10 with value: 0.8870781284392321.
# [I 2024-03-22 07:26:36,366] Trial 11 finished with value: 0.8817017843532106 and parameters: {'learning_rate': 0.09126965294854372, 'max_depth': 1, 'subsample': 0.9909799998379618, 'min_child_weight': 16}. Best is trial 10 with value: 0.8870781284392321.
# [I 2024-03-22 07:26:39,196] Trial 12 finished with value: 0.8626308158836359 and parameters: {'learning_rate': 0.06463786963776413, 'max_depth': 3, 'subsample': 0.8173965834746466, 'min_child_weight': 16}. Best is trial 10 with value: 0.8870781284392321.
# [I 2024-03-22 07:26:40,822] Trial 13 finished with value: 0.8790136123101999 and parameters: {'learning_rate': 0.0726386654562631, 'max_depth': 1, 'subsample': 0.8637345069671933, 'min_child_weight': 16}. Best is trial 10 with value: 0.8870781284392321.
# [I 2024-03-22 07:26:42,382] Trial 14 finished with value: 0.5 and parameters: {'learning_rate': 0.04368165743250176, 'max_depth': 3, 'subsample': 0.07232151768705014, 'min_child_weight': 16}. Best is trial 10 with value: 0.8870781284392321.
# [I 2024-03-22 07:26:44,861] Trial 15 finished with value: 0.8897663004822429 and parameters: {'learning_rate': 0.09696991752037765, 'max_depth': 1, 'subsample': 0.8505546385401402, 'min_child_weight': 9}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:26:48,215] Trial 16 finished with value: 0.8651498118143138 and parameters: {'learning_rate': 0.039957457252443054, 'max_depth': 4, 'subsample': 0.6922115160238869, 'min_child_weight': 8}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:26:50,567] Trial 17 finished with value: 0.8762408522110228 and parameters: {'learning_rate': 0.04144741001773291, 'max_depth': 2, 'subsample': 0.8401714205431817, 'min_child_weight': 9}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:26:54,007] Trial 18 finished with value: 0.8570852956852815 and parameters: {'learning_rate': 0.09529600474341994, 'max_depth': 7, 'subsample': 0.8923422990026126, 'min_child_weight': 5}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:26:56,344] Trial 19 finished with value: 0.871033684237334 and parameters: {'learning_rate': 0.007189336411665814, 'max_depth': 2, 'subsample': 0.7485116518803461, 'min_child_weight': 11}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:26:59,833] Trial 20 finished with value: 0.867922571913491 and parameters: {'learning_rate': 0.02512945543691765, 'max_depth': 4, 'subsample': 0.6120466881708875, 'min_child_weight': 5}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:27:01,447] Trial 21 finished with value: 0.8871627164953986 and parameters: {'learning_rate': 0.09547112642076627, 'max_depth': 1, 'subsample': 0.9867953633385063, 'min_child_weight': 15}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:27:03,069] Trial 22 finished with value: 0.8738064443365112 and parameters: {'learning_rate': 0.05468899610477288, 'max_depth': 1, 'subsample': 0.921760453869753, 'min_child_weight': 18}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:27:05,321] Trial 23 finished with value: 0.8544817116984372 and parameters: {'learning_rate': 0.09812433504083314, 'max_depth': 2, 'subsample': 0.7905494935317706, 'min_child_weight': 14}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:27:06,950] Trial 24 finished with value: 0.8846437205647208 and parameters: {'learning_rate': 0.03241024465010776, 'max_depth': 1, 'subsample': 0.9038049112363893, 'min_child_weight': 10}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:27:10,079] Trial 25 finished with value: 0.8545662997546037 and parameters: {'learning_rate': 0.06110375415945206, 'max_depth': 4, 'subsample': 0.6398753408078335, 'min_child_weight': 14}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:27:12,117] Trial 26 finished with value: 0.8019870916807191 and parameters: {'learning_rate': 0.0012157491805661678, 'max_depth': 2, 'subsample': 0.9969616384076107, 'min_child_weight': 18}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:27:14,972] Trial 27 finished with value: 0.8708645081250012 and parameters: {'learning_rate': 0.05303855447743918, 'max_depth': 3, 'subsample': 0.30181160396666223, 'min_child_weight': 7}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:27:19,033] Trial 28 finished with value: 0.8517935396554265 and parameters: {'learning_rate': 0.08050273077099135, 'max_depth': 6, 'subsample': 0.7864313597785655, 'min_child_weight': 11}. Best is trial 15 with value: 0.8897663004822429.
# [I 2024-03-22 07:27:20,732] Trial 29 finished with value: 0.876663792491855 and parameters: {'learning_rate': 0.028881654020706325, 'max_depth': 1, 'subsample': 0.8729940680799283, 'min_child_weight': 15}. Best is trial 15 with value: 0.8897663004822429.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [07:27:20] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best hyperparameters: {'learning_rate': 0.09696991752037765, 'max_depth': 1, 'subsample': 0.8505546385401402, 'min_child_weight': 9}
# Best accuracy: 0.8897663004822429
# [I 2024-03-22 07:27:20,951] A new study created in memory with name: no-name-4d875871-949f-4b41-899c-16fac722e134
# Tuning XGBoost for target: Dirtiness
# [I 2024-03-22 07:27:23,210] Trial 0 finished with value: 0.5881340186406278 and parameters: {'learning_rate': 0.04994482828982846, 'max_depth': 2, 'subsample': 0.4547860218523173, 'min_child_weight': 9}. Best is trial 0 with value: 0.5881340186406278.
# [I 2024-03-22 07:27:28,042] Trial 1 finished with value: 0.5 and parameters: {'learning_rate': 0.001392121846971164, 'max_depth': 7, 'subsample': 0.49460216926631934, 'min_child_weight': 12}. Best is trial 0 with value: 0.5881340186406278.
# [I 2024-03-22 07:27:33,630] Trial 2 finished with value: 0.5881340186406278 and parameters: {'learning_rate': 0.011092360985342995, 'max_depth': 7, 'subsample': 0.757076545965407, 'min_child_weight': 5}. Best is trial 0 with value: 0.5881340186406278.
# [I 2024-03-22 07:27:36,525] Trial 3 finished with value: 0.5869535801920611 and parameters: {'learning_rate': 0.09926510588270429, 'max_depth': 3, 'subsample': 0.6619446389954492, 'min_child_weight': 3}. Best is trial 0 with value: 0.5881340186406278.
# [I 2024-03-22 07:27:40,866] Trial 4 finished with value: 0.5 and parameters: {'learning_rate': 0.0014127200522694, 'max_depth': 7, 'subsample': 0.2384147291694787, 'min_child_weight': 7}. Best is trial 0 with value: 0.5881340186406278.
# [I 2024-03-22 07:27:42,505] Trial 5 finished with value: 0.5386692045925013 and parameters: {'learning_rate': 0.011884633626120264, 'max_depth': 1, 'subsample': 0.47981222768240384, 'min_child_weight': 18}. Best is trial 0 with value: 0.5881340186406278.
# [I 2024-03-22 07:27:49,124] Trial 6 finished with value: 0.5506452524966929 and parameters: {'learning_rate': 0.0018667159563770144, 'max_depth': 10, 'subsample': 0.9188284241065029, 'min_child_weight': 16}. Best is trial 0 with value: 0.5881340186406278.
# [I 2024-03-22 07:27:50,826] Trial 7 finished with value: 0.5 and parameters: {'learning_rate': 0.004458484288226349, 'max_depth': 1, 'subsample': 0.4270054762854025, 'min_child_weight': 10}. Best is trial 0 with value: 0.5881340186406278.
# [I 2024-03-22 07:27:54,345] Trial 8 finished with value: 0.5695797275600569 and parameters: {'learning_rate': 0.07157518072110594, 'max_depth': 7, 'subsample': 0.22924004658689123, 'min_child_weight': 8}. Best is trial 0 with value: 0.5881340186406278.
# [I 2024-03-22 07:27:57,751] Trial 9 finished with value: 0.56519372721673 and parameters: {'learning_rate': 0.006288166695761553, 'max_depth': 6, 'subsample': 0.07467283713631204, 'min_child_weight': 3}. Best is trial 0 with value: 0.5881340186406278.
# [I 2024-03-22 07:28:01,257] Trial 10 finished with value: 0.5880497016085873 and parameters: {'learning_rate': 0.02800295202753119, 'max_depth': 4, 'subsample': 0.6949366400591249, 'min_child_weight': 14}. Best is trial 0 with value: 0.5881340186406278.
# [I 2024-03-22 07:28:07,192] Trial 11 finished with value: 0.5819773606244509 and parameters: {'learning_rate': 0.028056401712318664, 'max_depth': 10, 'subsample': 0.9070773719040415, 'min_child_weight': 6}. Best is trial 0 with value: 0.5881340186406278.
# [I 2024-03-22 07:28:11,033] Trial 12 finished with value: 0.5850556896325393 and parameters: {'learning_rate': 0.026853169732747085, 'max_depth': 4, 'subsample': 0.7077665547301497, 'min_child_weight': 1}. Best is trial 0 with value: 0.5881340186406278.
# [I 2024-03-22 07:28:16,313] Trial 13 finished with value: 0.5910437135846351 and parameters: {'learning_rate': 0.012937319612022586, 'max_depth': 8, 'subsample': 0.7795014457958174, 'min_child_weight': 10}. Best is trial 13 with value: 0.5910437135846351.
# [I 2024-03-22 07:28:20,934] Trial 14 finished with value: 0.5730796417283477 and parameters: {'learning_rate': 0.046591720500559736, 'max_depth': 9, 'subsample': 0.3353248994084635, 'min_child_weight': 11}. Best is trial 13 with value: 0.5910437135846351.
# [I 2024-03-22 07:28:23,821] Trial 15 finished with value: 0.5853086407286607 and parameters: {'learning_rate': 0.018143036277542816, 'max_depth': 3, 'subsample': 0.5946537498287574, 'min_child_weight': 20}. Best is trial 13 with value: 0.5910437135846351.
# [I 2024-03-22 07:28:28,623] Trial 16 finished with value: 0.5850556896325393 and parameters: {'learning_rate': 0.055088740754242554, 'max_depth': 9, 'subsample': 0.8284981762201828, 'min_child_weight': 9}. Best is trial 13 with value: 0.5910437135846351.
# [I 2024-03-22 07:28:32,767] Trial 17 finished with value: 0.5652780442487705 and parameters: {'learning_rate': 0.004006052840873499, 'max_depth': 5, 'subsample': 0.556791947013894, 'min_child_weight': 13}. Best is trial 13 with value: 0.5910437135846351.
# [I 2024-03-22 07:28:34,964] Trial 18 finished with value: 0.5740071290807929 and parameters: {'learning_rate': 0.015921909184931134, 'max_depth': 2, 'subsample': 0.9981257332712627, 'min_child_weight': 15}. Best is trial 13 with value: 0.5910437135846351.
# [I 2024-03-22 07:28:39,596] Trial 19 finished with value: 0.5826518968807747 and parameters: {'learning_rate': 0.006733710005238727, 'max_depth': 8, 'subsample': 0.36354275288234916, 'min_child_weight': 9}. Best is trial 13 with value: 0.5910437135846351.
# [I 2024-03-22 07:28:44,098] Trial 20 finished with value: 0.5625369833688441 and parameters: {'learning_rate': 0.0025853430030527602, 'max_depth': 5, 'subsample': 0.8056550319060934, 'min_child_weight': 11}. Best is trial 13 with value: 0.5910437135846351.
# [I 2024-03-22 07:28:50,954] Trial 21 finished with value: 0.5912966646807566 and parameters: {'learning_rate': 0.010032428958861446, 'max_depth': 8, 'subsample': 0.776049524675314, 'min_child_weight': 5}. Best is trial 21 with value: 0.5912966646807566.
# [I 2024-03-22 07:28:56,910] Trial 22 finished with value: 0.5942063596247639 and parameters: {'learning_rate': 0.007054717716395659, 'max_depth': 8, 'subsample': 0.6092898391486851, 'min_child_weight': 5}. Best is trial 22 with value: 0.5942063596247639.
# [I 2024-03-22 07:29:03,182] Trial 23 finished with value: 0.5912123476487161 and parameters: {'learning_rate': 0.007037378743825587, 'max_depth': 8, 'subsample': 0.6224370543850882, 'min_child_weight': 4}. Best is trial 22 with value: 0.5942063596247639.
# [I 2024-03-22 07:29:10,117] Trial 24 finished with value: 0.591549615776878 and parameters: {'learning_rate': 0.007182447848467271, 'max_depth': 9, 'subsample': 0.5758721583052347, 'min_child_weight': 3}. Best is trial 22 with value: 0.5942063596247639.
# [I 2024-03-22 07:29:18,182] Trial 25 finished with value: 0.5738384950167119 and parameters: {'learning_rate': 0.00356005021410623, 'max_depth': 9, 'subsample': 0.5663368413494761, 'min_child_weight': 2}. Best is trial 22 with value: 0.5942063596247639.
# [I 2024-03-22 07:29:25,882] Trial 26 finished with value: 0.5941220425927234 and parameters: {'learning_rate': 0.00846218360696237, 'max_depth': 10, 'subsample': 0.8800694605595896, 'min_child_weight': 6}. Best is trial 22 with value: 0.5942063596247639.
# [I 2024-03-22 07:29:36,542] Trial 27 finished with value: 0.579489250840646 and parameters: {'learning_rate': 0.005703621177524662, 'max_depth': 10, 'subsample': 0.8633947479168356, 'min_child_weight': 1}. Best is trial 22 with value: 0.5942063596247639.
# [I 2024-03-22 07:29:42,991] Trial 28 finished with value: 0.5877124334804253 and parameters: {'learning_rate': 0.00866306885862863, 'max_depth': 9, 'subsample': 0.997036602352693, 'min_child_weight': 6}. Best is trial 22 with value: 0.5942063596247639.
# [I 2024-03-22 07:29:48,308] Trial 29 finished with value: 0.5595429713927963 and parameters: {'learning_rate': 0.0028616506514619333, 'max_depth': 10, 'subsample': 0.40654509885496604, 'min_child_weight': 7}. Best is trial 22 with value: 0.5942063596247639.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [07:29:48] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best hyperparameters: {'learning_rate': 0.007054717716395659, 'max_depth': 8, 'subsample': 0.6092898391486851, 'min_child_weight': 5}
# Best accuracy: 0.5942063596247639
# [I 2024-03-22 07:29:49,018] A new study created in memory with name: no-name-13933f13-69c2-4836-9b4e-bc77e319573f
# Tuning XGBoost for target: Bumps
# [I 2024-03-22 07:29:52,245] Trial 0 finished with value: 0.5 and parameters: {'learning_rate': 0.0010711503182031915, 'max_depth': 2, 'subsample': 0.44853657395525687, 'min_child_weight': 12}. Best is trial 0 with value: 0.5.
# [I 2024-03-22 07:29:56,068] Trial 1 finished with value: 0.5028533681140334 and parameters: {'learning_rate': 0.0013541162127093619, 'max_depth': 4, 'subsample': 0.3424058150835391, 'min_child_weight': 8}. Best is trial 1 with value: 0.5028533681140334.
# [I 2024-03-22 07:30:00,809] Trial 2 finished with value: 0.6445928111444567 and parameters: {'learning_rate': 0.005095046575119053, 'max_depth': 6, 'subsample': 0.266934326704405, 'min_child_weight': 19}. Best is trial 2 with value: 0.6445928111444567.
# [I 2024-03-22 07:30:03,156] Trial 3 finished with value: 0.5689707473488861 and parameters: {'learning_rate': 0.003910084848309026, 'max_depth': 2, 'subsample': 0.3256826379227937, 'min_child_weight': 1}. Best is trial 2 with value: 0.6445928111444567.
# [I 2024-03-22 07:30:04,825] Trial 4 finished with value: 0.6017312965800385 and parameters: {'learning_rate': 0.021867484982442252, 'max_depth': 1, 'subsample': 0.9578365235526061, 'min_child_weight': 5}. Best is trial 2 with value: 0.6445928111444567.
# [I 2024-03-22 07:30:08,601] Trial 5 finished with value: 0.5970829657581757 and parameters: {'learning_rate': 0.0029421480137279002, 'max_depth': 4, 'subsample': 0.8142557097691331, 'min_child_weight': 9}. Best is trial 2 with value: 0.6445928111444567.
# [I 2024-03-22 07:30:10,362] Trial 6 finished with value: 0.5987878109967232 and parameters: {'learning_rate': 0.012087635953104903, 'max_depth': 1, 'subsample': 0.2587033626643805, 'min_child_weight': 3}. Best is trial 2 with value: 0.6445928111444567.
# [I 2024-03-22 07:30:13,794] Trial 7 finished with value: 0.6480966993509572 and parameters: {'learning_rate': 0.07093425632586364, 'max_depth': 4, 'subsample': 0.1359633006608964, 'min_child_weight': 14}. Best is trial 7 with value: 0.6480966993509572.
# [I 2024-03-22 07:30:21,207] Trial 8 finished with value: 0.654357014318899 and parameters: {'learning_rate': 0.005370269605989326, 'max_depth': 9, 'subsample': 0.6106897198781915, 'min_child_weight': 14}. Best is trial 8 with value: 0.654357014318899.
# [I 2024-03-22 07:30:25,806] Trial 9 finished with value: 0.6220104707916689 and parameters: {'learning_rate': 0.0038621597227050885, 'max_depth': 4, 'subsample': 0.6908308965230066, 'min_child_weight': 7}. Best is trial 8 with value: 0.654357014318899.
# [I 2024-03-22 07:30:33,261] Trial 10 finished with value: 0.6573635328861932 and parameters: {'learning_rate': 0.02991196843357917, 'max_depth': 10, 'subsample': 0.6410942731862881, 'min_child_weight': 17}. Best is trial 10 with value: 0.6573635328861932.
# [I 2024-03-22 07:30:40,782] Trial 11 finished with value: 0.6609127963992407 and parameters: {'learning_rate': 0.03445047969489168, 'max_depth': 10, 'subsample': 0.6219615164435912, 'min_child_weight': 17}. Best is trial 11 with value: 0.6609127963992407.
# [I 2024-03-22 07:30:47,984] Trial 12 finished with value: 0.6594769669316022 and parameters: {'learning_rate': 0.043080311365688496, 'max_depth': 10, 'subsample': 0.7458216205061023, 'min_child_weight': 19}. Best is trial 11 with value: 0.6609127963992407.
# [I 2024-03-22 07:30:54,996] Trial 13 finished with value: 0.6616622276250494 and parameters: {'learning_rate': 0.05956232823184069, 'max_depth': 8, 'subsample': 0.8066106297871091, 'min_child_weight': 20}. Best is trial 13 with value: 0.6616622276250494.
# [I 2024-03-22 07:31:00,866] Trial 14 finished with value: 0.6586469153936958 and parameters: {'learning_rate': 0.08915441248946775, 'max_depth': 8, 'subsample': 0.9336722564316196, 'min_child_weight': 20}. Best is trial 13 with value: 0.6616622276250494.
# [I 2024-03-22 07:31:06,440] Trial 15 finished with value: 0.6578364913139704 and parameters: {'learning_rate': 0.01523460074906298, 'max_depth': 7, 'subsample': 0.5050315131701382, 'min_child_weight': 17}. Best is trial 13 with value: 0.6616622276250494.
# [I 2024-03-22 07:31:12,717] Trial 16 finished with value: 0.6564691117273711 and parameters: {'learning_rate': 0.05405198481151385, 'max_depth': 8, 'subsample': 0.8315952981939907, 'min_child_weight': 16}. Best is trial 13 with value: 0.6616622276250494.
# [I 2024-03-22 07:31:20,137] Trial 17 finished with value: 0.6560510257633252 and parameters: {'learning_rate': 0.03312632093762428, 'max_depth': 9, 'subsample': 0.5814679438649335, 'min_child_weight': 12}. Best is trial 13 with value: 0.6616622276250494.
# [I 2024-03-22 07:31:26,553] Trial 18 finished with value: 0.6621202719985818 and parameters: {'learning_rate': 0.022927603398861154, 'max_depth': 7, 'subsample': 0.8620219922436942, 'min_child_weight': 15}. Best is trial 18 with value: 0.6621202719985818.
# [I 2024-03-22 07:31:31,512] Trial 19 finished with value: 0.6636590928596855 and parameters: {'learning_rate': 0.01853146151102691, 'max_depth': 6, 'subsample': 0.8632607008588915, 'min_child_weight': 14}. Best is trial 19 with value: 0.6636590928596855.
# [I 2024-03-22 07:31:36,605] Trial 20 finished with value: 0.6624549940273433 and parameters: {'learning_rate': 0.008243717299866919, 'max_depth': 6, 'subsample': 0.8944261692644971, 'min_child_weight': 11}. Best is trial 19 with value: 0.6636590928596855.
# [I 2024-03-22 07:31:41,734] Trial 21 finished with value: 0.660153868016248 and parameters: {'learning_rate': 0.007978723574700463, 'max_depth': 6, 'subsample': 0.9984551969543658, 'min_child_weight': 11}. Best is trial 19 with value: 0.6636590928596855.
# [I 2024-03-22 07:31:45,836] Trial 22 finished with value: 0.6628141272675343 and parameters: {'learning_rate': 0.016411884397886982, 'max_depth': 5, 'subsample': 0.8787682132108533, 'min_child_weight': 14}. Best is trial 19 with value: 0.6636590928596855.
# [I 2024-03-22 07:31:50,216] Trial 23 finished with value: 0.6600691674440265 and parameters: {'learning_rate': 0.008177147320426457, 'max_depth': 5, 'subsample': 0.8784195514817452, 'min_child_weight': 13}. Best is trial 19 with value: 0.6636590928596855.
# [I 2024-03-22 07:31:54,550] Trial 24 finished with value: 0.666258359257055 and parameters: {'learning_rate': 0.015983190981867654, 'max_depth': 5, 'subsample': 0.7488410377541124, 'min_child_weight': 10}. Best is trial 24 with value: 0.666258359257055.
# [I 2024-03-22 07:31:59,723] Trial 25 finished with value: 0.6644322318037986 and parameters: {'learning_rate': 0.016576203903047496, 'max_depth': 5, 'subsample': 0.7512427662185918, 'min_child_weight': 9}. Best is trial 24 with value: 0.666258359257055.
# [I 2024-03-22 07:32:02,609] Trial 26 finished with value: 0.650248051675791 and parameters: {'learning_rate': 0.01216774921383624, 'max_depth': 3, 'subsample': 0.7346877894848556, 'min_child_weight': 9}. Best is trial 24 with value: 0.666258359257055.
# [I 2024-03-22 07:32:07,123] Trial 27 finished with value: 0.6636848407080518 and parameters: {'learning_rate': 0.020819053276041506, 'max_depth': 5, 'subsample': 0.7361925418344966, 'min_child_weight': 5}. Best is trial 24 with value: 0.666258359257055.
# [I 2024-03-22 07:32:11,790] Trial 28 finished with value: 0.6635100226665485 and parameters: {'learning_rate': 0.026999293630647927, 'max_depth': 5, 'subsample': 0.7400786588534796, 'min_child_weight': 4}. Best is trial 24 with value: 0.666258359257055.
# [I 2024-03-22 07:32:14,701] Trial 29 finished with value: 0.651275292336568 and parameters: {'learning_rate': 0.01310465619558642, 'max_depth': 3, 'subsample': 0.4868651886749196, 'min_child_weight': 7}. Best is trial 24 with value: 0.666258359257055.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [07:32:14] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best hyperparameters: {'learning_rate': 0.015983190981867654, 'max_depth': 5, 'subsample': 0.7488410377541124, 'min_child_weight': 10}
# Best accuracy: 0.666258359257055
# [I 2024-03-22 07:32:15,226] A new study created in memory with name: no-name-2b550f96-6df5-4ff2-9ac5-9529dac89103
# Tuning XGBoost for target: Other_Faults
# [I 2024-03-22 07:32:18,069] Trial 0 finished with value: 0.6172119919897832 and parameters: {'learning_rate': 0.05124428588142677, 'max_depth': 3, 'subsample': 0.34592442513901644, 'min_child_weight': 12}. Best is trial 0 with value: 0.6172119919897832.
# [I 2024-03-22 07:32:26,074] Trial 1 finished with value: 0.5995075123421839 and parameters: {'learning_rate': 0.07300648736178333, 'max_depth': 10, 'subsample': 0.19668093565286304, 'min_child_weight': 6}. Best is trial 0 with value: 0.6172119919897832.
# [I 2024-03-22 07:32:32,828] Trial 2 finished with value: 0.5824688060961578 and parameters: {'learning_rate': 0.0017559953435704163, 'max_depth': 6, 'subsample': 0.3408136605918744, 'min_child_weight': 7}. Best is trial 0 with value: 0.6172119919897832.
# [I 2024-03-22 07:32:36,978] Trial 3 finished with value: 0.5845469882766013 and parameters: {'learning_rate': 0.0022144766974570864, 'max_depth': 5, 'subsample': 0.11635760990160135, 'min_child_weight': 14}. Best is trial 0 with value: 0.6172119919897832.
# [I 2024-03-22 07:32:41,967] Trial 4 finished with value: 0.6138244338897187 and parameters: {'learning_rate': 0.043225762662255175, 'max_depth': 7, 'subsample': 0.14052314591159992, 'min_child_weight': 20}. Best is trial 0 with value: 0.6172119919897832.
# [I 2024-03-22 07:32:51,379] Trial 5 finished with value: 0.5626609153316893 and parameters: {'learning_rate': 0.0010230444233161689, 'max_depth': 10, 'subsample': 0.4237985039261109, 'min_child_weight': 14}. Best is trial 0 with value: 0.6172119919897832.
# [I 2024-03-22 07:32:54,896] Trial 6 finished with value: 0.6220124293383951 and parameters: {'learning_rate': 0.02046222942499947, 'max_depth': 4, 'subsample': 0.6802462886838235, 'min_child_weight': 13}. Best is trial 6 with value: 0.6220124293383951.
# [I 2024-03-22 07:33:06,430] Trial 7 finished with value: 0.5697883545111339 and parameters: {'learning_rate': 0.0010382508807623783, 'max_depth': 9, 'subsample': 0.6928472885499019, 'min_child_weight': 11}. Best is trial 6 with value: 0.6220124293383951.
# [I 2024-03-22 07:33:09,312] Trial 8 finished with value: 0.6141739928596818 and parameters: {'learning_rate': 0.011376561719577584, 'max_depth': 3, 'subsample': 0.722443904660606, 'min_child_weight': 18}. Best is trial 6 with value: 0.6220124293383951.
# [I 2024-03-22 07:33:16,042] Trial 9 finished with value: 0.6197270052652615 and parameters: {'learning_rate': 0.011487763604975734, 'max_depth': 7, 'subsample': 0.5197420346089374, 'min_child_weight': 7}. Best is trial 6 with value: 0.6220124293383951.
# [I 2024-03-22 07:33:17,761] Trial 10 finished with value: 0.5986830142333545 and parameters: {'learning_rate': 0.020343099559392615, 'max_depth': 1, 'subsample': 0.8301079168454011, 'min_child_weight': 2}. Best is trial 6 with value: 0.6220124293383951.
# [I 2024-03-22 07:33:25,000] Trial 11 finished with value: 0.6140104458382369 and parameters: {'learning_rate': 0.005619407589318521, 'max_depth': 7, 'subsample': 0.5925939402839797, 'min_child_weight': 7}. Best is trial 6 with value: 0.6220124293383951.
# [I 2024-03-22 07:33:28,592] Trial 12 finished with value: 0.6187326087943485 and parameters: {'learning_rate': 0.019428018972129896, 'max_depth': 4, 'subsample': 0.9315169142818569, 'min_child_weight': 3}. Best is trial 6 with value: 0.6220124293383951.
# [I 2024-03-22 07:33:37,260] Trial 13 finished with value: 0.6171795295820748 and parameters: {'learning_rate': 0.007133556532085293, 'max_depth': 8, 'subsample': 0.5288673284261972, 'min_child_weight': 9}. Best is trial 6 with value: 0.6220124293383951.
# [I 2024-03-22 07:33:41,691] Trial 14 finished with value: 0.6204979286396298 and parameters: {'learning_rate': 0.0245604980451354, 'max_depth': 5, 'subsample': 0.645569518134947, 'min_child_weight': 16}. Best is trial 6 with value: 0.6220124293383951.
# [I 2024-03-22 07:33:45,184] Trial 15 finished with value: 0.6238285599087854 and parameters: {'learning_rate': 0.027044850890893226, 'max_depth': 4, 'subsample': 0.776696160480485, 'min_child_weight': 16}. Best is trial 15 with value: 0.6238285599087854.
# [I 2024-03-22 07:33:46,872] Trial 16 finished with value: 0.6012396052665316 and parameters: {'learning_rate': 0.034846585604664915, 'max_depth': 1, 'subsample': 0.9947207425207327, 'min_child_weight': 16}. Best is trial 15 with value: 0.6238285599087854.
# [I 2024-03-22 07:33:49,905] Trial 17 finished with value: 0.6055047069315003 and parameters: {'learning_rate': 0.005133429686394382, 'max_depth': 3, 'subsample': 0.7950026437175562, 'min_child_weight': 14}. Best is trial 15 with value: 0.6238285599087854.
# [I 2024-03-22 07:33:52,102] Trial 18 finished with value: 0.6219687344671496 and parameters: {'learning_rate': 0.08668961442219021, 'max_depth': 2, 'subsample': 0.8639021834678242, 'min_child_weight': 20}. Best is trial 15 with value: 0.6238285599087854.
# [I 2024-03-22 07:33:55,626] Trial 19 finished with value: 0.6209509909385188 and parameters: {'learning_rate': 0.015612002795470804, 'max_depth': 4, 'subsample': 0.7456374674779872, 'min_child_weight': 17}. Best is trial 15 with value: 0.6238285599087854.
# [I 2024-03-22 07:33:59,110] Trial 20 finished with value: 0.6245761362254358 and parameters: {'learning_rate': 0.030578776020633518, 'max_depth': 4, 'subsample': 0.9015513018935001, 'min_child_weight': 12}. Best is trial 20 with value: 0.6245761362254358.
# [I 2024-03-22 07:34:03,443] Trial 21 finished with value: 0.6268544444447058 and parameters: {'learning_rate': 0.031037024263337536, 'max_depth': 4, 'subsample': 0.8853818070022531, 'min_child_weight': 13}. Best is trial 21 with value: 0.6268544444447058.
# [I 2024-03-22 07:34:07,667] Trial 22 finished with value: 0.6274384737399116 and parameters: {'learning_rate': 0.03254113568885115, 'max_depth': 5, 'subsample': 0.9175509431400551, 'min_child_weight': 10}. Best is trial 22 with value: 0.6274384737399116.
# [I 2024-03-22 07:34:11,898] Trial 23 finished with value: 0.619208900533536 and parameters: {'learning_rate': 0.056172211566151264, 'max_depth': 5, 'subsample': 0.9120141714234264, 'min_child_weight': 10}. Best is trial 22 with value: 0.6274384737399116.
# [I 2024-03-22 07:34:16,933] Trial 24 finished with value: 0.6244663991732907 and parameters: {'learning_rate': 0.034168766765770256, 'max_depth': 6, 'subsample': 0.9893493044672345, 'min_child_weight': 9}. Best is trial 22 with value: 0.6274384737399116.
# [I 2024-03-22 07:34:19,148] Trial 25 finished with value: 0.6216762199455149 and parameters: {'learning_rate': 0.06440614074400594, 'max_depth': 2, 'subsample': 0.8874798600341197, 'min_child_weight': 11}. Best is trial 22 with value: 0.6274384737399116.
# [I 2024-03-22 07:34:24,264] Trial 26 finished with value: 0.6287396164401865 and parameters: {'learning_rate': 0.03677057309198029, 'max_depth': 6, 'subsample': 0.9444080669829852, 'min_child_weight': 9}. Best is trial 26 with value: 0.6287396164401865.
# [I 2024-03-22 07:34:29,231] Trial 27 finished with value: 0.625146933560978 and parameters: {'learning_rate': 0.041455218719990625, 'max_depth': 6, 'subsample': 0.9982448118213544, 'min_child_weight': 9}. Best is trial 26 with value: 0.6287396164401865.
# [I 2024-03-22 07:34:38,356] Trial 28 finished with value: 0.6215888302030241 and parameters: {'learning_rate': 0.014116398189558805, 'max_depth': 8, 'subsample': 0.816010932418202, 'min_child_weight': 6}. Best is trial 26 with value: 0.6287396164401865.
# [I 2024-03-22 07:34:42,873] Trial 29 finished with value: 0.6176791683789803 and parameters: {'learning_rate': 0.09600196502367432, 'max_depth': 5, 'subsample': 0.9410600216525065, 'min_child_weight': 4}. Best is trial 26 with value: 0.6287396164401865.
# /opt/conda/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [07:34:42] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best hyperparameters: {'learning_rate': 0.03677057309198029, 'max_depth': 6, 'subsample': 0.9444080669829852, 'min_child_weight': 9}
# Best accuracy: 0.6287396164401865
